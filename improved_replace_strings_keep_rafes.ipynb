# %%
import os
import unicodedata
import re

# %%
def chapterTitle(line_in):
    #line_in = line_in.strip()
    print('in chapterTitle, line_in == ' + line_in)
    chapter_string = re.compile('\u0043' + '\u0068' + '\u0061' + '\u0070' +
    '\u0074' + '\u0065' + '\u0072')
    line_in = re.sub(chapter_string, 'פרק', line_in)
    print(line_in.index('פרק'))
    line_list = line_in.split()
    print(str(line_list))
    #line_list[0] = line_list[0].replace('Chapter', 'פרק')
    if line_list[0] == 'פרק':
        print('1')
        if line_list[1].isdigit():
            line_list[1] = convert_number(line_list[1]) ## This is the verse number
        else: ## decode the digit from unicode
            print('2')
            digit = unicodedata.normalize('NFKD', line_list[1]).encode('ascii', 'ignore').decode()
            line_list[1] = digit
            line_list[1] = convert_number(line_list[1])
    elif line_list[1] == 'פרק':
        print('3')
        if line_list[0].isdigit():
            print('4')
            line_list[0] = convert_number(line_list[0])
        else:
            print('5')
            digit = unicodedata.normalize('NFKD', line_list[0]).encode('ascii', 'ignore').decode()
            line_list[0] = digit
            line_list[0] = convert_number(line_list[0])    
        line_list.reverse()
       
            
    line_in = " ".join(line_list)
    #line_list.clear()
    print('in chapterTitle, line_in now equals: ' + line_in)
    return line_in

# %%
def convert_number(num_in): ##This method converts a Roman numeral to a Hebrew number
    HebrewNumber = ""
    if num_in == "1":
        HebrewNumber = "א"
    elif num_in ==  "2":
        HebrewNumber = "ב"
    elif num_in == "3":
        HebrewNumber = "ג"
    elif num_in == "4":
        HebrewNumber = "ד"
    elif num_in ==  "5":
        HebrewNumber = "ה"
    elif num_in ==  "6":
        HebrewNumber = "ו"
    elif num_in ==  "7":
        HebrewNumber = "ז"
    elif num_in == "8":
        HebrewNumber = "ח"
    elif num_in == "9":
        HebrewNumber = "ט"
    elif num_in == "10":
        HebrewNumber = "י"
    elif num_in == "11":
        HebrewNumber = "יא"
    elif num_in == "12":
        HebrewNumber = "יב"
    elif num_in == "13":
        HebrewNumber = "יג"
    elif num_in == "14":
        HebrewNumber = "יד"
    elif num_in == "15":
        HebrewNumber = "טו"
    elif num_in == "16":
        HebrewNumber = "טז"
    elif num_in == "17":
        HebrewNumber = "יז"
    elif num_in == "18":
        HebrewNumber = "יח"
    elif num_in == "19":
        HebrewNumber = "יט"
    elif num_in == "20":
        HebrewNumber = "כ"
    elif num_in == "21":
        HebrewNumber = "כא"
    elif num_in == "22":
        HebrewNumber = "כב"
    elif num_in == "23":
        HebrewNumber = "כג"
    elif num_in == "24":
        HebrewNumber = "כד"
    elif num_in == "25":
        HebrewNumber = "כה"
    elif num_in == "26":
        HebrewNumber = "כו"
    elif num_in == "27":
        HebrewNumber = "כז"
    elif num_in == "28":
        HebrewNumber = "כח"
    elif num_in == "29":
        HebrewNumber = "כט"
    elif num_in == "30":
        HebrewNumber = "ל"
    elif num_in == "31":
        HebrewNumber = "לא"
    elif num_in == "32":
        HebrewNumber = "לב"
    elif num_in == "33":
        HebrewNumber = "לג"
    elif num_in == "34":
        HebrewNumber = "לד"
    elif num_in == "35":
        HebrewNumber = "לה"
    elif num_in == "36":
        HebrewNumber = "לו"
    elif num_in == "37":
        HebrewNumber = "לז"
    elif num_in == "38":
        HebrewNumber = "לח"
    elif num_in == "39":
        HebrewNumber = "לט"
    elif num_in == "40":
        HebrewNumber = "מ"
    elif num_in == "41":
        HebrewNumber = "מא"
    elif num_in == "42":
        HebrewNumber = "מב"
    elif num_in == "43":
        HebrewNumber = "מג"
    elif num_in == "44":
        HebrewNumber = "מד"
    elif num_in == "45":
        HebrewNumber = "מה"
    elif num_in == "46":
        HebrewNumber = "מו"
    elif num_in == "47":
        HebrewNumber = "מז"
    elif num_in == "48":
        HebrewNumber = "מח"
    elif num_in == "49":
        HebrewNumber = "מט"
    elif num_in == "50":
        HebrewNumber = "נ"
    elif num_in == "51":
        HebrewNumber = "נא"
    elif num_in == "52":
        HebrewNumber = "נב"
    elif num_in == "53":
        HebrewNumber = "נג"
    elif num_in == "54":
         HebrewNumber = "נד"
    elif num_in == "55":
        HebrewNumber = "נה"
    elif num_in == "56":
        HebrewNumber = "נו"
    elif num_in == "57":
        HebrewNumber = "נז"
    elif num_in == "58":
        HebrewNumber = "נח"
    elif num_in == "59":
        HebrewNumber = "נט"
    elif num_in == "60":
        HebrewNumber = "ס"
    elif num_in == "61":
        HebrewNumber = "סא"
    elif num_in == "62":
        HebrewNumber = "סב"
    elif num_in == "63":
        HebrewNumber = "סג"
    elif num_in == "64":
        HebrewNumber = "סד"
    elif num_in == "65":
        HebrewNumber = "סה"
    elif num_in == "66":
        HebrewNumber = "סו"
    elif num_in == "67":
        HebrewNumber = "סז"
    elif num_in == "68":
        HebrewNumber = "סח"
    elif num_in == "69":
        HebrewNumber = "סט"
    elif num_in == "70":
        HebrewNumber = "ע"
    elif num_in == "71":
        HebrewNumber = "עא"
    elif num_in == "72":
        HebrewNumber = "עב"
    elif num_in == "73":
        HebrewNumber = "עג"
    elif num_in == "74":
        HebrewNumber = "עד"
    elif num_in == "75":
        HebrewNumber = "עה"
    elif num_in == "76":
        HebrewNumber = "עו"
    elif num_in == "77":
        HebrewNumber = "עז"
    elif num_in == "78":
        HebrewNumber = "עח"
    elif num_in == "79":
        HebrewNumber = "עט"
    elif num_in == "80":
        HebrewNumber = "פ"
    elif num_in == "81":
        HebrewNumber = "פא"
    elif num_in == "82":
        HebrewNumber = "פב"
    elif num_in == "83":
        HebrewNumber = "פג"
    elif num_in == "84":
        HebrewNumber = "פד"
    elif num_in == "85":
        HebrewNumber = "פה"
    elif num_in == "86":
        HebrewNumber = "פו"
    elif num_in == "87":
        HebrewNumber = "פז"
    elif num_in == "88":
        HebrewNumber = "פח"
    elif num_in == "89":
        HebrewNumber = "פט"
    elif num_in == "90":
        HebrewNumber = "צ"
    elif num_in == "91":
        HebrewNumber = "צא"
    elif num_in == "92":
        HebrewNumber = "צב"
    elif num_in == "93":
        HebrewNumber = "צג"
    elif num_in == "94":
        HebrewNumber = "צד"
    elif num_in == "95":
        HebrewNumber = "צה"
    elif num_in == "96":
        HebrewNumber = "צו"
    elif num_in == "97":
        HebrewNumber = "צז"
    elif num_in == "98":
        HebrewNumber = "צח"
    elif num_in == "99":
        HebrewNumber = "צט"
    elif num_in == "100":
        HebrewNumber = "ק"
    elif num_in == "101":
        HebrewNumber = "קא"
    elif num_in == "102":
        HebrewNumber = "קב"
    elif num_in == "103":
        HebrewNumber = "קג"
    elif num_in == "104":
        HebrewNumber = "קד"
    elif num_in == "105":
        HebrewNumber = "קה"
    elif num_in == "106":
        HebrewNumber = "קו"
    elif num_in == "107":
        HebrewNumber = "קז"
    elif num_in == "108":
        HebrewNumber = "קח"
    elif num_in == "109":
        HebrewNumber = "קט"
    elif num_in == "110":
        HebrewNumber = "קי"
    elif num_in == "111":
        HebrewNumber = "קיא"
    elif num_in == "112":
        HebrewNumber = "קיב"
    elif num_in == "113":
        HebrewNumber = "קיג"
    elif num_in == "114":
        HebrewNumber = "קיד"
    elif num_in == "115":
        HebrewNumber = "קטו"
    elif num_in == "116":
        HebrewNumber = "קטז"
    elif num_in == "117":
        HebrewNumber = "קיז"
    elif num_in == "118":
        HebrewNumber = "קיח"
    elif num_in == "119":
        HebrewNumber = "קיט"
    elif num_in == "120":
        HebrewNumber = "קכ"
    elif num_in == "121":
        HebrewNumber = "קכא"
    elif num_in == "122":
        HebrewNumber = "קכב"
    elif num_in == "123":
        HebrewNumber = "קכג"
    elif num_in == "124":
        HebrewNumber = "קכד"
    elif num_in == "125":
        HebrewNumber = "קכה"
    elif num_in == "126":
        HebrewNumber = "קכו"
    elif num_in == "127":
        HebrewNumber = "קכז"
    elif num_in == "128":
        HebrewNumber = "קכח"
    elif num_in == "129":
        HebrewNumber = "קכט"
    elif num_in == "130":
        HebrewNumber = "קל"
    elif num_in == "131":
        HebrewNumber = "קלא"
    elif num_in == "132":
        HebrewNumber = "קלב"
    elif num_in == "133":
        HebrewNumber = "קלג"
    elif num_in == "134":
        HebrewNumber = "קלד"
    elif num_in == "135":
        HebrewNumber = "קלה"
    elif num_in == "136":
        HebrewNumber = "קלו"
    elif num_in == "137":
        HebrewNumber = "קלז"
    elif num_in == "138":
        HebrewNumber = "קלח"
    elif num_in == "139":
        HebrewNumber = "קלט"
    elif num_in == "140":
        HebrewNumber = "קמ"
    elif num_in == "141":
        HebrewNumber = "קמא"
    elif num_in == "142":
        HebrewNumber = "קמב"
    elif num_in == "143":
        HebrewNumber = "קמג"
    elif num_in == "144":
        HebrewNumber = "קמד"
    elif num_in == "145":
        HebrewNumber = "קמה"
    elif num_in == "146":
        HebrewNumber = "קמו"
    elif num_in == "147":
        HebrewNumber = "קמז"
    elif num_in == "148":
        HebrewNumber = "קמח"
    elif num_in == "149":
        HebrewNumber = "קמט"
    elif num_in == "150":
        HebrewNumber = "קנ"
    elif num_in == "151":
        HebrewNumber = "קנא"
    elif num_in == "152":
        HebrewNumber = "קנב"
    elif num_in == "153":
        HebrewNumber = "קנג"
    elif num_in == "154":
        HebrewNumber = "קנד"
    elif num_in == "155":
        HebrewNumber = "קנה"
    elif num_in == "156":
        HebrewNumber = "קנו"
    elif num_in == "157":
        HebrewNumber = "קנז"
    elif num_in == "158":
        HebrewNumber = "קנח"
    elif num_in == "159":
        HebrewNumber = "קנט"
    elif num_in == "160":
        HebrewNumber = "קס"
    elif num_in == "161":
        HebrewNumber = "קסא"
    elif num_in == "162":
        HebrewNumber = "קסב"
    elif num_in == "163":
        HebrewNumber = "קסג"
    elif num_in == "164":
        HebrewNumber = "קסד"
    elif num_in == "165":
        HebrewNumber = "קסה"
    elif num_in == "166":
        HebrewNumber = "קסו"
    elif num_in == "167":
        HebrewNumber = "קסז"
    elif num_in == "168":
        HebrewNumber = "קסח"
    elif num_in == "169":
        HebrewNumber = "קסט"
    elif num_in == "170":
        HebrewNumber = "קע"
    elif num_in == "171":
        HebrewNumber = "קעא"
    elif num_in == "172":
        HebrewNumber = "קעב"
    elif num_in == "173":
        HebrewNumber = "קעג"
    elif num_in == "174":
        HebrewNumber = "קעד"
    elif num_in == "175":
        HebrewNumber = "קעה"
    elif num_in == "176":
        HebrewNumber = "קעו"

    return HebrewNumber

# %%
def convert_book_title(line_in):
    bookTitle = line_in
    bookTitle = bookTitle.strip()
    print('BookTitle == ' + bookTitle)

    convertedBookTitle = ""

    if bookTitle == "Genesis":
        convertedBookTitle = "בראשית" ## Pentateuch
    elif bookTitle == "Exodus":
        convertedBookTitle = "שמות"
    elif bookTitle == "Leviticus":
        convertedBookTitle = "ויקרא"
    elif bookTitle == "Numbers":
        convertedBookTitle = "במדבר"
    elif bookTitle == "Deuteronomy":
        convertedBookTitle = "דברים"
    elif bookTitle == "Joshua":
        convertedBookTitle = "יהושע" ## Former Prophets
    elif bookTitle == "Judges":
        convertedBookTitle = "שופטים"
    elif bookTitle == "1Samuel":
        convertedBookTitle = "שמואל א"
    elif bookTitle == "2Samuel":
        convertedBookTitle = "שמואל ב"
    elif bookTitle == "1Kings":
        convertedBookTitle = "מלכים א"
    elif bookTitle ==  "2Kings":
        convertedBookTitle = "מלכים ב"
    elif bookTitle == "Isaiah":
        convertedBookTitle = "ישעיהו"
    elif bookTitle ==  "Jeremiah":
        convertedBookTitle = "ירמיהו"
    elif bookTitle == "Ezekiel":
        convertedBookTitle = "יחזקאל"
    elif bookTitle ==  "Hosea": ##Twelve Minor Prophets
        convertedBookTitle = "הושע"
    elif bookTitle == "Joel":
        convertedBookTitle = "יואל"
    elif bookTitle == "Amos":
        convertedBookTitle = "עמוס"
    elif bookTitle == "Obadiah":
        convertedBookTitle = "עבדיה"
    elif bookTitle == "Jonah":
        convertedBookTitle = "יונה"
    elif bookTitle == "Micah":
        convertedBookTitle = "מיכה"
    elif bookTitle == "Nahum":
        convertedBookTitle = "נחום"
    elif bookTitle == "Habakkuk":
        convertedBookTitle = "חבקוק"
    elif bookTitle == "Zephaniah":
        convertedBookTitle = "צפניה"
    elif bookTitle == "Haggai":
        convertedBookTitle = "חגי"
    elif bookTitle == "Zechariah":
        convertedBookTitle = "זכריה"
    elif bookTitle == "Malachi":
        convertedBookTitle = "מלאכי"
    elif bookTitle == "Psalms":
        convertedBookTitle = "תהלים" ##The Writings
    elif bookTitle == "Job":
        convertedBookTitle = "איוב"
    elif bookTitle == "Proverbs":
        convertedBookTitle = "משלי"
    elif bookTitle == "Ruth":
        convertedBookTitle = "רות"
    elif bookTitle == "Song of Solomon":
        convertedBookTitle = "שיר השירים"
    elif bookTitle == "Ecclesiastes":
        convertedBookTitle = "קהלת"
    elif bookTitle == "Lamentations":
        convertedBookTitle = "איכה"
    elif bookTitle == "Esther":
        convertedBookTitle = "אסתר"
    elif bookTitle == "Daniel":
        convertedBookTitle = "דניאל"
    elif bookTitle == "Ezra":
        convertedBookTitle = "עזרה"
    elif bookTitle == "Nehemiah":
        convertedBookTitle = "נחמיה"
    elif bookTitle == "I Chronicles":
        convertedBookTitle = "דברי הימים א"
    elif bookTitle == "II Chronicles":
        convertedBookTitle = "דברי הימים ב"

    print('In converted BookTitle, convertedBookTitle == ' + convertedBookTitle)
    line_in = convertedBookTitle
    line_in = line_in + chr(10)
    print('Line in now equals: ' + line_in)

    return line_in

# %%
def convert_verse_number(line_in):
    line_list = line_in.split()
    formatted_number = ''
    formatted_number = formatted_number = '[\u200f' + convert_number(line_list[0]) + ']'
    line_list[0] = formatted_number
    print('line_list[0] == ' + line_list[0])
    print('line_list == ' + str(line_list))
    line_in = " ".join(line_list)
    print('in convert_verse_number, line_in == ' + line_in)
    #line_in = line + chr(10)
    return line_in

# %%
def insert_parashah(keter_line_in, ginsburg_line_in):
    #if 'פרשת' in keter_line_in:
    parashah_marker = ''
    keter_word_list = keter_line_in.split()
    if '}' in keter_word_list[i + 1]:
        parashah_marker = '\u200f' + keter_word_list[i] + ' ' + keter_word_list[i + 1]
    elif '}' in keter_word_list[i + 2]:
        parashah_marker = '\u200f' + keter_word_list[i] + ' ' + keter_word_list[i + 1] + ' ' + keter_word_list[i + 2]
    ginsburg_line_in = " ".join(keter_word_list)
    ginsburg_line_in = parashah_marker + ' ' + ginsburg_line_in
    return ginsburg_line_in

# %%
def insert_parashiot(keter_line_in, ginsburg_line_in):
    #if 'פרשת' not in keter_line_in
     parashiot_list = ['[\u200fשני]', 
                      '[\u200fשלישי]', 
                      '[\u200fרביעי]', 
                      '[\u200fחמישי]', 
                      '[\u200fששי]', 
                      '[\u200fשביעי]', 
                      '[\u200fמפטיר]']
     
     for j in parashiot_list:
         if i in keter_line_in:
            print("i == " + i)
            ginsburg_line_in = j + ginsburg_line_in
            break
         else:
            continue
    
     return ginsburg_line_in

# %%
def replace_strings(line_in):
    ################################
    # Replace letter-nikkud-dagesh 
    # with composite character.
    ################################
    line = line_in
    
    ############################################################################
    
    #convert the Qadmas to Pashtas
    Kadma = '\u05A8'
    Pashta = '\u0599'
    sof_pasuq = '\u05C3'
    error_counter = 0
    
    line_list = line.split()
    for i in range(len(line_list)):
        #print('in loop')
        if Kadma in line_list[i] and Pashta in line_list[i] and line_list[i] != 'וְי֨וֺם֙':
            line_list[i] = line_list[i].replace(Kadma, Pashta)
            #print('replaced Kadma')
            
    line = ' '.join(line_list)
    
    #Delete the rafes for comparison purposes
    
    match_rafe = re.compile('\u05BF')
    match_bet_w_rafe = re.compile('\uFB4C')
    match_kaf_w_rafe = re.compile('\uFB4D')
    match_peh_w_rafe = re.compile('\uFB4E')
    #if re.search(match_rafe, line):
    #    line = re.sub(match_rafe, '', line)
    #if re.search(match_bet_w_rafe, line):
    #    line = re.sub(match_bet_w_rafe, '\u05D1', line)
    #if re.search(match_kaf_w_rafe, line):
    #    line = re.sub(match_kaf_w_rafe, '\u05DB', line)
    #if re.search(match_peh_w_rafe, line):
    #    line = re.sub(match_peh_w_rafe, '\u05E4', line)
        
    # Aleph composite letters
    match_aleph_dagesh = re.compile('\u05d0' + '\u05bc')
    if re.search(match_aleph_dagesh, line):
        line = re.sub(match_aleph_dagesh, '\ufb30', line)
    match_aleph_patach = re.compile('\u05D0' + '\u05B7')
    if re.search(match_aleph_patach, line):
        line = re.sub(match_aleph_patach, '\uFB2E', line)
    match_aleph_qamats = re.compile('\u05d0' + '\u05B8')
    if re.search(match_aleph_qamats, line):
        line = re.sub(match_aleph_qamats, '\uFB2F', line)
    match_alef_yetiv_patach = re.compile('\u05d0' + '\u059a' + '\u05b7')
    alefpatach_yetiv = '\uFB2E' + '\u059a'
    if re.search(match_alef_yetiv_patach, line):
        line = re.sub(match_alef_yetiv_patach, alefpatach_yetiv, line)
    match_alef_telisha_patach = re.compile('\u05d0' + '\u05a0' + '\u05b7')
    alefpatach_telisha = '\ufb2e' + '\u05a0'
    if re.search(match_alef_telisha_patach, line):
        line = re.sub(match_alef_telisha_patach, alefpatach_telisha, line)
    match_alef_meteg_patach = re.compile('\u05d0' + '\u05bd' + '\u05b7')
    alefpatach_meteg = '\ufb2e' + '\u05bd'
    if re.search(match_alef_meteg_patach, line):
        line = re.sub(match_alef_meteg_patach, alefpatach_meteg, line)
    match_alef_hiriq_yetiv = re.compile('\u05d0' + '\u05b4' + '\u059a')
    match_alef_yetiv_hiriq = re.compile('\u05d0' + '\u059a' + '\u05b4')
    alefhiriq_yetiv = '\uFB30' + '\u059a'
    if re.search(match_alef_hiriq_yetiv, line):
        line = re.sub(match_alef_hiriq_yetiv, alefhiriq_yetiv, line)
    if re.search(match_alef_yetiv_hiriq, line):
        line = re.sub(match_alef_yetiv_hiriq, alefhiriq_yetiv, line)
    
    

    ## Letter ב
    match_bet_dagesh = re.compile('\u05d1' + '\u05bc')
    if re.search(match_bet_dagesh, line):
        line = re.sub(match_bet_dagesh, '\uFB31', line)
    match_bet_sheva_dagesh = re.compile('\u05d1' + '\u05B0' + '\u05bc')
    if re.search(match_bet_sheva_dagesh, line):
        line = re.sub(match_bet_sheva_dagesh, '\uFB31' + '\u05b0', line)
    match_beit_dagesh_sheva = re.compile('\u05d1' + '\u05bc' + '\u05b0')
    if re.search(match_beit_dagesh_sheva, line):
        line = re.sub(match_beit_dagesh_sheva, '\uFB31' + '\u05b0', line)
    match_bet_hiriq_dagesh = re.compile('\u05d1' + '\u05B4' + '\u05bc')
    if re.search(match_bet_hiriq_dagesh, line):
        line = re.sub(match_bet_hiriq_dagesh, '\uFB31' + '\u05B4', line)
    match_bet_patach_dagesh = re.compile('\u05d1' + '\u05B7' + '\u05bc')
    if re.search(match_bet_patach_dagesh, line):
        line = re.sub(match_bet_patach_dagesh,'\uFB31' + '\u05B7', line)
    match_bet_dagesh_qamats = re.compile('\u05d1' + '\u05bc' + '\u05b8')
    if re.search(match_bet_dagesh_qamats, line):
        line = re.sub(match_bet_dagesh_qamats, '\uFB31' + '\u05B8', line)
    match_bet_qamats_dagesh = re.compile('\u05d1' + '\u05b8' + '\u05bc')
    if re.search(match_bet_qamats_dagesh, line):
        line = re.sub(match_bet_qamats_dagesh, '\ufb31' + '\u05b8', line)
    match_bet_tsere_dagesh = re.compile('\u05D1' + '\u05B5' + '\u05bc')
    if re.search(match_bet_tsere_dagesh, line):
        line = re.sub(match_bet_tsere_dagesh, '\ufb31' + '\u05B5', line)  
    match_bet_segol_dagesh = re.compile('\u05d1' + '\u05B6' + '\u05bc' )
    if re.search(match_bet_segol_dagesh, line):
        line = re.sub(match_bet_segol_dagesh, '\uFB31' + '\u05B6', line)
    match_bet_holam_dagesh = re.compile('\u05d1' + '\u05b9' + '\u05bc')
    if re.search(match_bet_holam_dagesh, line):
        #print('found match for bet_holam_dagesh in line, line == ' + line)
        line = re.sub(match_bet_holam_dagesh, '\uFB31' + '\u05B9', line)
        #print('replace line == ' + line)
    match_bet_holam_meteg_dagesh = re.compile('\u05d1' + '\u05b9' + '\u05bd' + '\u05bc' )
    if re.search(match_bet_holam_meteg_dagesh, line):
        #print('found match for match_bet_holam_dagesh_meteg')
        line = re.sub(match_bet_holam_meteg_dagesh, '\uFB31' + '\u05B9' + '\u05bd', line)
        #print('line after == ' + line)
    match_bet_qubuts_dagesh = re.compile('\u05D1' + '\u05BB' + '\u05bc')
    if re.search(match_bet_qubuts_dagesh, line):
        line = re.sub(match_bet_qubuts_dagesh, '\uFB31' + '\u05BB', line)
    
    ### Letter ג
    match_gimel_dagesh = re.compile('\u05d2' + '\u05bc')
    if re.search(match_gimel_dagesh, line):
        line = re.sub(match_gimel_dagesh, '\uFB32', line)
    match_gimel_sheva_dagesh = re.compile('\u05D2' + '\u05B0' + '\u05BC')
    if re.search(match_gimel_sheva_dagesh, line):
        line = re.sub(match_gimel_sheva_dagesh, '\uFB32' + '\u05B0' , line)
    match_gimel_hiriq_dagesh = re.compile('\u05d2' + '\u05b4' + '\u05bc')
    if re.search(match_gimel_hiriq_dagesh, line):
        line = re.sub(match_gimel_hiriq_dagesh, '\uFB32' + '\u05B4', line)
    match_gimel_patach_dagesh = re.compile('גַּ')
    if re.search(match_gimel_patach_dagesh, line):
        line = re.sub(match_gimel_patach_dagesh, '\uFB32' + '\u05B7', line)
    match_gimel_qamats_dagesh = re.compile('\u05d2' + '\u05b8' + '\u05bc')
    if re.search(match_gimel_qamats_dagesh, line):
        line = re.sub(match_gimel_qamats_dagesh, '\uFB32' + '\u05B8', line)
    match_gimel_segol_dagesh  = re.compile('\u05d2' + '\u05b6' + '\u05bc')
    if re.search(match_gimel_segol_dagesh, line):
        line = re.sub(match_gimel_segol_dagesh, '\uFB32' + '\u05B6', line)
    match_gimel_holam_dagesh = re.compile('\u05d2' + '\u05b9' + '\u05bc')
    if re.search(match_gimel_holam_dagesh, line):
        line = re.sub(match_gimel_holam_dagesh, '\uFB32' + '\u05B9', line)
    match_gimel_qubuts_dagesh = re.compile('\u05d2' + '\u05bb' + '\u05bc')
    if re.search(match_gimel_qubuts_dagesh, line):
        line = re.sub(match_gimel_qubuts_dagesh, '\uFB32' + '\u05BB', line )
    match_gimel_tsere_dagesh = '\u05d2' + '\u05b5' + '\u05bc'
    if re.search(match_gimel_tsere_dagesh, line):
        line = re.sub(match_gimel_tsere_dagesh, '\ufb32' + '\u05b5', line)
    
    ## Letter ד
    match_dalet_dagesh = re.compile('\u05d3' + '\u05bc')
    if re.search(match_dalet_dagesh, line):
        line = re.sub(match_dalet_dagesh, '\ufb33', line)
    match_dalet_sheva_dagesh = re.compile('דְּ')
    if re.search(match_dalet_sheva_dagesh, line):
        line = re.sub(match_dalet_sheva_dagesh, '\uFB33' + '\u05BC', line)
    match_dalet_hiriq_dagesh = re.compile('דִּ')
    if re.search(match_dalet_hiriq_dagesh, line):
        line = re.sub(match_dalet_hiriq_dagesh, '\uFB33' + '\u05B4', line)
    match_dalet_patach_dagesh = re.compile('דַּ')
    if re.search(match_dalet_patach_dagesh, line):
        line = re.sub(match_dalet_patach_dagesh, '\uFB33' + '\u05B7', line)
    match_dalet_qamats_dagesh = re.compile('דָּ')
    if re.search(match_dalet_qamats_dagesh, line):
        line = re.sub(match_dalet_qamats_dagesh, '\uFB33' + '\u05B8', line)
    match_dalet_segol_dagesh = re.compile('דֶּ')
    if re.search(match_dalet_segol_dagesh, line):
        line = re.sub(match_dalet_segol_dagesh,'\uFB33' + '\u05B6' , line)
    match_dalet_tsere_dagesh = re.compile('\u05d3' + '\u05b5' + '\u05bc')
    if re.search(match_dalet_tsere_dagesh, line):
        line = re.sub(match_dalet_tsere_dagesh, '\ufb33' + '\u05b5', line)
    match_dalet_holam_dagesh  = re.compile('דֹּ')
    if re.search(match_dalet_holam_dagesh, line):
        line = re.sub(match_dalet_holam_dagesh, '\uFB33' + '\u05B9', line)
    match_dalet_qubuts_sheva = re.compile('דֻּ')
    if re.search(match_dalet_qubuts_sheva, line):
        line = re.sub(match_dalet_qubuts_sheva, '\uFB33' + '\u05BB', line)
        
    ### ה
    match_he_mappiq = re.compile('\u05d4' + '\u05bc')
    if re.search(match_he_mappiq, line):
        line = re.sub(match_he_mappiq, '\ufb34', line)
    
    ### Letter ו
    match_vav_qadma_holam = re.compile('\u05d5' + '\u05a8' + '\u05b9')
    if re.search(match_vav_qadma_holam, line):
        line = re.sub(match_vav_qadma_holam, '\ufb4b' + '\u05a8', line)
    match_vav_holam = re.compile('\u05d5' + '\u05b9')
    if re.search(match_vav_holam, line):
        line = re.sub(match_vav_holam, '\ufb4b', line)
    match_vav_w_dagesh = re.compile('\u05d5' + '\u05bc')
    if re.search(match_vav_w_dagesh, line):
        line = re.sub(match_vav_w_dagesh, '\ufb35', line)
    match_vav_sheva_dagesh = re.compile('\u05d5' + '\u05b0' + '\u05bc')
    if re.search(match_vav_sheva_dagesh, line):
        line = re.sub(match_vav_sheva_dagesh, '\uFB35' + '\u05B0', line)
    match_vav_hiriq_dagesh = re.compile('\u05d5' + '\u05b4' + '\u05bc')
    if re.search(match_vav_hiriq_dagesh, line):
        line = re.sub(match_vav_hiriq_dagesh, '\uFB35' + '\u05B4', line)
    match_vav_patach_dagesh = re.compile('וַּ')
    if re.search(match_vav_patach_dagesh, line):
        line = re.sub(match_vav_patach_dagesh, '\uFB35' + '\u05B7', line)
    match_vav_qamats_dagesh = re.compile('וָּ')
    if re.search(match_vav_qamats_dagesh, line):
        line = re.sub(match_vav_qamats_dagesh, '\uFB35' + '\u05B8', line)
    match_vav_segol_dagesh = re.compile('ןֶּ')
    if re.search(match_vav_segol_dagesh, line):
        line = re.sub(match_vav_segol_dagesh, '\uFB35' + '\u05B6', line)
    match_vav_tsere_dagesh = re.compile('\u05d5' + '\u05b5' + '\u05bc')
    if re.search(match_vav_tsere_dagesh, line):
        line = re.sub(match_vav_tsere_dagesh, '\ufb35' + '\u05b5', line)
    match_vav_segol_dagesh = re.compile('\u05d5' + '\u05b6' + '\u05bc')
    if re.search(match_vav_segol_dagesh, line):
        line = re.sub(match_vav_segol_dagesh, '\ufb35' + '\u05b6', line)
    match_vav_holam_dagesh  = re.compile('\u05d5' + '\u05b9' + '\u05bc')
    if re.search(match_vav_holam_dagesh, line):
        line = re.sub(match_vav_holam_dagesh, '\uFB35' + '\u05b9', line)
    match_vav_holam_haser = re.compile('\u05D5' + '\u05BA')
    if re.search(match_vav_holam_haser, line):
        line = re.sub(match_vav_holam_haser, '\uFB4B', line)

    match_het_patach_yod_dagesh = re.compile('\u05D7' + '\u05b7' + '\u05d9' + '\u05bc' )
    if re.search(match_het_patach_yod_dagesh, line):
        line = re.sub(match_het_patach_yod_dagesh, '\u05d7' + '\u05b7' + '\ufb39', line)
    
    ## Letter ז
     
    match_zain_dagesh = re.compile('זּ')
    if re.search(match_zain_dagesh, line):
        line = re.sub(match_zain_dagesh, '\uFB36', line )
    match_zain_sheva_dagesh = re.compile('זְּ')
    if re.search(match_zain_sheva_dagesh, line):
        line = re.sub(match_zain_sheva_dagesh, '\uFB36' + '\u05BC', line)
    match_zain_hiriq_dagesh = re.compile('זִּ')
    if re.search(match_zain_hiriq_dagesh, line):
        line = re.sub(match_zain_hiriq_dagesh,'\uFB36' + '\u05B4', line)
    match_zain_patach_dagesh = re.compile('זַּ')
    if re.search(match_zain_patach_dagesh, line):
        line = re.sub(match_zain_patach_dagesh, '\uFB36' + '\u05B7', line)
    match_zain_qamats_dagesh = re.compile('זָּ')
    if re.search(match_zain_qamats_dagesh, line):
        line = re.sub(match_zain_qamats_dagesh, '\uFB36' + '\u05B8', line)
    match_zain_tsere_dagesh = re.compile('\u05d6' + '\u05b5' + '\u05bc')
    if re.search(match_zain_tsere_dagesh, line):
        line = re.sub(match_zain_tsere_dagesh, '\ufb36' + '\u05b5', line)
    match_zain_segol_dagesh = re.compile('זֶּ')
    if re.search(match_zain_segol_dagesh, line):
        line = re.sub(match_zain_segol_dagesh, '\uFB36' + '\u05B6', line)
    match_zain_holam_dagesh  = re.compile('זֹּ')
    if re.search(match_zain_holam_dagesh, line):
        line = re.sub(match_zain_holam_dagesh, '\uFB36' + '\u05B9', line)


        
    ## Letter ט
    
    match_tet_sheva_dagesh = re.compile('\u05D8' + '\u05B0' + '\u05BC')
    if re.search(match_tet_sheva_dagesh, line):
        line = re.sub(match_tet_sheva_dagesh, '\uFB38' + '\u05B0', line)
    match_tet_dagesh_sheva = re.compile('\u05D8' + '\u05BC' + '\u05B0')
    if (match_tet_dagesh_sheva, line):
        line = re.sub(match_tet_sheva_dagesh, '\uFB38' + '\u05B0', line)
    match_tet_hiriq_dagesh = re.compile('\u05D8' + '\u05BC' + '\u05B4')
    if re.search(match_tet_hiriq_dagesh, line):
        line = re.sub(match_tet_hiriq_dagesh, '\uFB38' + '\u05B4', line)
    match_tet_patach_dagesh = re.compile('\u05D8' + '\u05B7' + '\u05BC')
    if re.search(match_tet_patach_dagesh, line):
        line = re.sub(match_tet_patach_dagesh, '\uFB38' + '\u05B7', line)
    match_tet_qamats_dagesh = re.compile('\u05D8' + '\u05B8' + '\u05BC')
    if re.search(match_tet_qamats_dagesh, line):
        line = re.sub(match_tet_qamats_dagesh, '\uFB38' + '\u05B8', line)
    match_tet_segol_dagesh = re.compile('\u05D8' + '\u05B6' + '\u05BC')
    if re.search(match_tet_segol_dagesh, line):
        line = re.sub(match_tet_segol_dagesh, '\uFB38' + '\u05B6', line)
    match_tet_tsere_dagesh = re.compile('\u05d8' + '\u05b5' + '\u05bc')
    if re.search(match_tet_tsere_dagesh, line):
        line = re.sub(match_tet_tsere_dagesh, '\ufb38' + '\u05b5', line)
    match_tet_holam_dagesh  = re.compile('\u05d8' + '\u05B9' + '\u05bc')
    if re.search(match_tet_holam_dagesh, line):
        line = re.sub(match_tet_holam_dagesh, '\uFB38' + '\u05B9', line)
    match_tet_qubuts_dagesh = re.compile('\u05d8' + '\u05BB' + '\u05bc')
    if re.search(match_tet_qubuts_dagesh, line):
        line = re.sub(match_tet_qubuts_dagesh, '\uFB38' + '\u05BB', line)
    match_tet_dagesh = re.compile('\u05D8' + '\u05BC')
    if re.search(match_tet_dagesh, line):
        line = re.sub(match_tet_dagesh, '\ufb38', line)
        
    ## Letter י
    
    match_yod_dagesh_patach = re.compile ('\u05d9' + '\u05BC' + '\u05B7')
    if re.search(match_yod_dagesh_patach, line):
        line = re.sub(match_yod_dagesh_patach, '\uFB39' + '\u05B7', line)
        print('found match_yod_dagesh_patach, line == ' + line)
    
    match_yod_dagesh = re.compile('\u05d9' + '\u05bc' + '\u05bc')
    if re.search(match_yod_dagesh, line):
        line = re.sub(match_yod_dagesh, '\uFB39', line)
    
    match_yod_dagesh_tiphecha = re.compile('\u05d9' + '\u05bc' + '\u0596')
    if re.search(match_yod_dagesh_tiphecha, line):
        line = re.sub(match_yod_dagesh_tiphecha, '\ufb39' + '\u0596', line)
    
    match_yod_dagesh_munach = re.compile('\u05d9' + '\u05bc' + '\u05A3')
    if re.search(match_yod_dagesh_munach, line):
        line = re.sub(match_yod_dagesh_munach, '\ufb39' + '\u05A3', line)
    
    match_yod_sheva_dagesh = re.compile('\u05d9' + '\u05B0' + '\u05BC')
    if re.search(match_yod_sheva_dagesh, line):
        line = re.sub(match_yod_sheva_dagesh, '\uFB39' + '\u05BC', line)
    
    match_yod_dagesh_sheva = re.compile('\u05d9' + '\u05BC' + '\u05B0')
    if re.search(match_yod_dagesh_sheva, line):
        line = re.sub(match_yod_dagesh_sheva, '\uFB39' + '\u05BC', line)
    
    match_yod_hiriq_dagesh = re.compile('\u05d9' + '\u05b4' + '\u05BC')
    if re.search(match_yod_hiriq_dagesh, line):
        line = re.sub(match_yod_hiriq_dagesh, '\uFB39' + '\u05B4', line)
    
    match_yod_dagesh_hiriq = re.compile('\u05d9' + '\u05BC' + '\u05B4')
    if re.search(match_yod_dagesh_hiriq, line):
        line = re.sub(match_yod_dagesh_hiriq, '\uFB39' + '\u05B4', line)
    
    match_yod_qamats_dagesh = re.compile('\u05d9' + '\u05B8' + '\u05BC')
    if re.search(match_yod_qamats_dagesh, line):
        line = re.sub(match_yod_qamats_dagesh,'\uFB39' + '\u05B8', line)
    
    match_yod_dagesh_qamats = re.compile('\u05d9' + '\u05BC' + '\u05B8' )
    if re.search(match_yod_dagesh_qamats, line):
        line = re.sub(match_yod_dagesh_qamats,'\uFB39' + '\u05B8', line)
    
    match_yod_segol_dagesh = re.compile('\u05d9' + '\u05B6' + '\u05BC')
    if re.search(match_yod_segol_dagesh, line):
        line = re.sub(match_yod_segol_dagesh, '\uFB39' + '\u05B6', line)
    
    match_yod_tsere_dagesh_merkha = re.compile('\u05d9' + '\u05b5'+ '\u05bc'+ '\u05a5' )
    if re.search(match_yod_tsere_dagesh_merkha, line):
        line = re.sub(match_yod_tsere_dagesh_merkha, '\uFB39' + '\u05b5' + '\u05a5', line )
        
    match_yod_dagesh_tsere_merkha = re.compile('\u05d9' + '\u05bc' + '\u05b5' + '\u05a5' )
    if re.search(match_yod_dagesh_tsere_merkha, line):
        line = re.sub(match_yod_dagesh_tsere_merkha, '\uFB39' + '\u05b5' + '\u05a5', line )
        
    match_yod_dagesh_tsere_munach = re.compile('\u05d9' + '\u05bc' + '\u05b5' + '\u05a3' )
    if re.search(match_yod_dagesh_tsere_munach, line):
        line = re.sub(match_yod_dagesh_tsere_munach, '\uFB39' + '\u05b5' + '\u05a3', line )
        
    match_vav_patah_yod_dagesh_tsere_tsadi_tsere = re.compile('\u05d5' + '\u05b7' + '\u05d9' + '\u05bc' + '\u05e6' + '\u05b5')
    vav_patach_yodwithdagesh_tsere_tsadi_tsadi_tsere = '\u05d5' + '\ufb39' + '\u05b5' + '\u05b5'
    if re.search(match_vav_patah_yod_dagesh_tsere_tsadi_tsere, line):
        line = re.sub(match_vav_patah_yod_dagesh_tsere_tsadi_tsere, vav_patach_yodwithdagesh_tsere_tsadi_tsadi_tsere, line)
        
    match_vav_patah_yod_dagesh_tsere_darga = re.compile('\u05d5'+ '\u05b7' + '\u05d9' + '\u05bc' + '\u05b5' + '\u05a7')
    vav_patah_yoddagesh_tsere_darga = '\u05d5'+ '\u05b7' + '\ufb39' + '\u05b5' + '\u05a7'
    if re.search(match_vav_patah_yod_dagesh_tsere_tsadi_tsere, line):
        line = re.sub(match_vav_patah_yod_dagesh_tsere_darga,vav_patah_yoddagesh_tsere_darga, line)
        
    match_yod_tsere_dagesh_munach = re.compile('\u05d9' + '\u05b5' + '\u05bc' + '\u05a3')
    if re.search(match_yod_tsere_dagesh_munach, line):
        line = re.sub(match_yod_tsere_dagesh_munach, '\uFB39' + '\u05b5' + '\u05a3', line )
    
    match_yod_holam_dagesh  = re.compile('\u05d9' + '\u05B9' + '\u05BC')
    if re.search(match_yod_holam_dagesh, line):
        line = re.sub(match_yod_holam_dagesh, '\uFB39' + '\u05B9', line)
    
    match_yod_dagesh_holam = re.compile('\u05d9' + '\u05bc' + '\u05b9')
    if re.search(match_yod_dagesh_holam, line):
        line = re.sub(match_yod_dagesh_holam, '\uFB39'  + '\u05b9', line)

    match_yod_qubuts_dagesh  = re.compile('\u05d9' + '\u05BB' + '\u05BC')
    if re.search(match_yod_qubuts_dagesh, line):
        line = re.sub(match_yod_qubuts_dagesh, '\uFB39' + '\u05BB', line)
        
    match_yod_dagesh_qubuts = re.compile('\u05d9' + '\u05BC' + '\u05BB')
    if re.search(match_yod_dagesh_qubuts, line):
        line = re.sub(match_yod_dagesh_qubuts, '\uFB39' + '\u05BB', line)
        
    
    match_yod_patach_dagesh = re.compile('\u05d9' + '\u05B7' + '\u05BC')
   
    if re.search(match_yod_patach_dagesh, line):
        print('in replace_strings, about to process yod patach dagesh, line == ' + line)
        line = re.sub(match_yod_patach_dagesh, '\uFB39' + '\u05B7', line)
        print('processed line == ' + line)
    
    match_yod_tsere_dagesh_merkha = re.compile('\u05d9' + '\u05b5'+ '\u05bc'+ '\u05a5' )
    if re.search(match_yod_tsere_dagesh_merkha, line):
        print('in replace_strings, about to process yod tsere dagesh merkha, line == ' + line)
        line = re.sub(match_yod_tsere_dagesh_merkha, '\uFB39' + '\u05b5' + '\u05a5', line )
        print('line after: ' + line)
        
    match_yod_tsere_dagesh_munach = re.compile('\u05d9' + '\u05b5'+ '\u05bc'+ '\u05a3')
    if re.search(match_yod_tsere_dagesh_munach, line):
        line = re.sub(match_yod_tsere_dagesh_munach, '\ufb39' + '\u05b5' + '\u05a3', line)
    
    match_yod_merkha_dagesh_holam = re.compile('\u05d9' + '\u05a5' + '\u05bc' + '\u05b9')
    if re.search(match_yod_merkha_dagesh_holam, line):
        line = re.sub(match_yod_merkha_dagesh_holam, '\ufb39' + '\u05b9' + '\u05a5', line)
    
    
    ### Letter כ
    
    match_kaf_dagesh = re.compile('\u05db' + '\u05bc')
    if re.search(match_kaf_dagesh, line):
        line = re.sub(match_kaf_dagesh, '\uFB3B', line)
    
    match_kaf_sheva_dagesh = re.compile('\u05db' + '\u05b0' + '\u05bc')
    if re.search(match_kaf_sheva_dagesh, line):
        #print('Matched kaf_sheva_dagesh, line == ' + line)
        line = re.sub(match_kaf_sheva_dagesh, '\ufb3b' + '\u05b0' , line)
        #print('line after: ' + line)
    
    match_kaf_dagesh_hiriq = re.compile('\u05db' + '\u05bc' + '\u05b4')
    if re.search(match_kaf_dagesh_hiriq, line):
        line = re.sub(match_kaf_dagesh_hiriq, '\ufb3b' + '\u05b4', line)
    
    match_kafdagesh_hiriq_telisha = re.compile('\ufb3b' + '\u05b4' + '\u05a0')
    if re.search(match_kafdagesh_hiriq_telisha, line):
        line = re.sub(match_kafdagesh_hiriq_telisha, '\ufb3b' + '\u05a0' + '\u05b4', line)
    
    match_kaf_hiriq_dagesh = re.compile('\u05db' + '\u05b4' + '\u05bc')
    if re.search(match_kaf_hiriq_dagesh, line):
        line = re.sub(match_kaf_hiriq_dagesh, '\ufb3b' + '\u05b4', line)
    match_kaf_patach_dagesh = re.compile('\u05DB' + '\u05B7' + '\u05bc')
    if re.search(match_kaf_patach_dagesh, line):
        line = re.sub(match_kaf_patach_dagesh, '\ufb3b' + '\u05B7', line)
    
    match_kaf_qamats_dagesh = re.compile('\u05DB' + '\u05B8' + '\u05BC')
    if re.search(match_kaf_qamats_dagesh, line):
        line = re.sub(match_kaf_qamats_dagesh, '\ufb3b' + '\u05B8', line)
    
    match_kaf_segol_dagesh  = re.compile('\u05DB' + '\u05B6' + '\u05BC')
    if re.search(match_kaf_segol_dagesh, line):
        line = re.sub(match_kaf_segol_dagesh, '\ufb3b' + '\u05b6', line)
    
    match_kaf_tsere_dagesh = re.compile('\u05db' + '\u05B5' + '\u05BC')
    if re.search(match_kaf_tsere_dagesh, line):
        line = re.sub(match_kaf_tsere_dagesh, '\ufb3b' + '\u05B5', line)
    
    match_kaf_holam_dagesh  = re.compile('\u05db' + '\u05B9' + '\u05BC')
    if re.search(match_kaf_holam_dagesh, line):
        line = re.sub(match_kaf_holam_dagesh, '\ufb3b' + '\u05B9', line)
    
    match_finalkaf_sheva_dagesh = re.compile('\u05da' + '\u05B0' + '\u05bc')
    if re.search(match_finalkaf_sheva_dagesh, line):
        line = re.sub(match_finalkaf_sheva_dagesh, '\uFB3A' + '\u05b0', line)
    
    match_kafdagesh_holam_yetiv = re.compile('\ufb3b' + '\u05b9' + '\u059a')
    kafdagesh_yetiv_holam = '\ufb3b' + '\u059a' + '\u05b9'
    if re.search(match_kafdagesh_holam_yetiv, line):
        line = re.sub(match_kafdagesh_holam_yetiv, kafdagesh_yetiv_holam, line)
        
    match_final_kaph_w_dagesh = re.compile('\u05da' + '\u05bc')
    if re.search(match_final_kaph_w_dagesh, line):
        line = re.sub(match_final_kaph_w_dagesh, '\ufb3a', line)
    
    match_finalkaf_sheva_dagesh = re.compile('\u05da' + '\u05b8' + '\u05B0' + '\u05bc')
    if re.search(match_finalkaf_sheva_dagesh, line):
        line = re.sub(match_finalkaf_sheva_dagesh, '\ufb3a' + '\u05b8', line)
    
    match_finalkaf_dagesh_qamats = re.compile('\u05da' + '\u05bc' + '\u05b8')
    if re.search(match_finalkaf_dagesh_qamats, line):
        line = re.sub(match_finalkaf_dagesh_qamats, '\ufb3a' + '\u05b8', line)
        
    ## Letter ל
    match_lamed_qamats_telisha = re.compile('\u05dc' + '\u05b8' + '\u05a0')
    lamed_telisha_qamats = '\u05dc' + '\u05a0' + '\u05b8'
    if re.search(match_lamed_qamats_telisha, line):
        line = re.sub(match_lamed_qamats_telisha, lamed_telisha_qamats, line)
    
    match_lamed_dagesh = re.compile('\u05DC' + '\u05bc')
    if re.search(match_lamed_dagesh, line):
        line = re.sub(match_lamed_dagesh, '\uFB3C', line)
    
    match_lamed_sheva_dagesh = re.compile('\u05dc' + '\u05b0' + '\u05bc')
    if re.search(match_lamed_sheva_dagesh, line):
        line = re.sub(match_lamed_sheva_dagesh, '\ufb3c' + '\u05b0', line)
    
    match_lamed_tsere_dagesh = re.compile('\u05dc' + '\u05b5' + '\u05bc')
    if re.search(match_lamed_tsere_dagesh, line):
        line = re.sub(match_lamed_tsere_dagesh, '\ufb3c' + '\u05b5', line)
    
    match_lamed_hiriq_dagesh = re.compile('\u05dc' + '\u05b4' + '\u05bc')
    if re.search(match_lamed_hiriq_dagesh, line):
        line = re.sub(match_lamed_hiriq_dagesh, '\ufb3c' + '\u05b4', line)
    
    match_lamed_patach_dagesh = re.compile('\u05dc' + '\u05b7' + '\u05bc')
    if re.search(match_lamed_patach_dagesh, line):
        line = re.sub(match_lamed_patach_dagesh, '\uFB3C' + '\u05B7', line)
    
    match_lamed_qamats_dagesh = re.compile('\u05dc' + '\u05b8' + '\u05bc')
    if re.search(match_lamed_qamats_dagesh, line):
        line = re.sub(match_lamed_qamats_dagesh, '\uFB3C' + '\u05B8', line)
    
    match_lamed_segol_dagesh  = re.compile('\u05dc' + '\u05b6' + '\u05bc')
    if re.search(match_lamed_segol_dagesh, line):
        line = re.sub(match_lamed_segol_dagesh , '\ufb3c' + '\u05b6', line)
    
    match_lamed_holam_dagesh  = re.compile('\u05dc' + '\u05b9' + '\u05bc')
    if re.search(match_lamed_holam_dagesh, line):
        line = re.sub(match_lamed_holam_dagesh, '\uFB3C' + '\u05b9', line)
    
    match_lamed_qubuts_dagesh = re.compile('\u05dc' + '\u05bb' + '\u05bc')
    if re.search(match_lamed_qubuts_dagesh, line):
        line = re.sub(match_lamed_qubuts_dagesh, '\ufb3c' + '\u05bb', line)
    
    match_lamed_alef_holam_haser_vav = re.compile('\u05dc' + '\u05d0' + '\u05ba')
    if re.search(match_lamed_alef_holam_haser_vav, line):
        line = re.sub(match_lamed_alef_holam_haser_vav, '\u05dc' + '\u05b9' + '\u05d0', line)
    
    match_lamed_munah_alef_holam_haser_for_vav = '\u05dc' + '\u05a3' + '\u05d0' + '\u05ba'
    lamed_holam_munah_alef = '\u05dc' + '\u05b9' + '\u05a3' + '\u05d0'
    if re.search(match_lamed_munah_alef_holam_haser_for_vav, line):
        line = re.sub(match_lamed_munah_alef_holam_haser_for_vav, lamed_holam_munah_alef, line)
    
    match_lamed_mahapakh_alef_holam_haser_for_vav = re.compile('\u05dc' + '\u05a4' + '\u05d0'  + '\u05ba')
    lamed_holam_mahapakh_alef = '\u05dc' + '\u05b9' + '\u05a4' + '\u05d0' 
    if re.search(match_lamed_mahapakh_alef_holam_haser_for_vav, line):
        line = re.sub(match_lamed_mahapakh_alef_holam_haser_for_vav, lamed_holam_mahapakh_alef, line)
    
                                           
    ### Letter מ
    match_mem_dagesh = re.compile('\u05de' + '\u05bc')
    if re.search(match_mem_dagesh, line):
        #print('matched mem with dagesh')
        line = re.sub(match_mem_dagesh, '\ufb3e', line)
    
    match_mem_sheva_dagesh = re.compile('\u05de' + '\u05B0' + '\u05BC')
    if re.search(match_mem_sheva_dagesh, line):
        line = re.sub(match_mem_sheva_dagesh, '\ufb3e' + '\u05B0', line)
    
    match_mem_hiriq_dagesh = re.compile('\u05de'+ '\u05B4' + '\u05bc')
    if re.search(match_mem_hiriq_dagesh, line):
        line = re.sub(match_mem_hiriq_dagesh, '\ufb3e' + '\u05B4', line)
    
    if re.search(match_mem_hiriq_dagesh, line):
        line = re.sub(match_mem_hiriq_dagesh, '\ufb3e' + '\u05B7', line)
    
    match_mem_qamats_dagesh = re.compile('\u05de'+ '\u05B8' + '\u05bc')
    if re.search(match_mem_qamats_dagesh, line):
        line = re.sub(match_mem_qamats_dagesh, '\ufb3e' + '\u05B8', line)
    
    match_shin_qamats_meteg_shin_dot = re.compile('\u05e9' + '\u05b8' + '\u05bd' + '\u05c1')
    if re.search(match_shin_qamats_meteg_shin_dot, line):
        line = re.sub(match_shin_qamats_meteg_shin_dot, '\ufb2a' + '\u05b8' + '\u05bd', line)
    
    match_mem_patach_dagesh = re.compile('\u05de'+ '\u05B7' + '\u05bc')
    if re.search(match_mem_patach_dagesh, line):
        line = re.sub(match_mem_patach_dagesh, '\ufb3e' + '\u05B7', line)
    
    match_mem_segol_dagesh  = re.compile('\u05de'+ '\u05B6' + '\u05bc')
    if re.search(match_mem_segol_dagesh, line):
        line = re.sub(match_mem_segol_dagesh, '\ufb3e' + '\u05B6', line)
    
    match_mem_tsere_dagesh = re.compile('\u05de'+ '\u05b5' + '\u05bc')
    if re.search(match_mem_tsere_dagesh, line):
        line = re.sub(match_mem_tsere_dagesh, '\uFB3E' + '\u05b5', line)
    
    match_mem_holam_dagesh  = re.compile('\u05de'+ '\u05B9' + '\u05bc')
    if re.search(match_mem_holam_dagesh, line):
        line = re.sub(match_mem_holam_dagesh, '\uFB3E' + '\u05b9', line)
    
    match_mem_qubuts_dagesh = re.compile('\u05de' + '\u05bb' + '\u05bc')
    if re.search(match_mem_qubuts_dagesh, line):
        line = re.sub(match_mem_qubuts_dagesh, '\ufb3e' + '\u05bb', line)
    
    ## Letter נ
    match_nun_dagesh = re.compile('\u05e0' + '\u05bc')
    if re.search(match_nun_dagesh, line):
        line = re.sub(match_nun_dagesh, '\ufb40', line)
    
    match_nun_sheva_dagesh = re.compile('\u05e0' + '\u05b0' + '\u05bc')
    if re.search(match_nun_sheva_dagesh, line):
        line = re.sub(match_nun_sheva_dagesh, '\ufb40' + '\u05b0', line)
    
    match_nun_hiriq_dagesh = re.compile('\u05e0' + '\u05b4' + '\u05bc')
    if re.search(match_nun_hiriq_dagesh, line):
        line = re.sub(match_nun_hiriq_dagesh, '\ufb40' + '\u05b4', line)
    
    match_nun_patach_dagesh = re.compile('\u05e0' + '\u05b7' + '\u05bc')
    if re.search(match_nun_patach_dagesh, line):
        line = re.sub(match_nun_patach_dagesh, '\ufb40' + '\u05b7', line)
    
    match_nun_qamats_dagesh = re.compile('\u05e0' + '\u05b8' + '\u05bc')
    if re.search(match_nun_qamats_dagesh, line):
        line = re.sub(match_nun_qamats_dagesh, '\ufb40' + '\u05b8', line)
    
    match_nun_segol_dagesh = re.compile('\u05e0' + '\u05b6' + '\u05bc')
    nundagesh_segol = '\uFB40' + '\u05b6'
    if re.search(match_nun_segol_dagesh, line):
        #print('match_nun_segol_dagesh: ' + str(match_nun_segol_dagesh))
        line = re.sub(match_nun_segol_dagesh, nundagesh_segol, line)
    
    match_nun_dagesh_segol = re.compile('\u05e0' + '\u05bc' + '\u05b6')
    #nundagesh_segol = '\uFB40' + '\u05b6'
    if re.search(match_nun_dagesh_segol, line):
        #print('match_nun_dagesh_segol: ' + match_nun_dagesh_segol)
        line = re.sub(match_nun_dagesh_segol, nundagesh_segol, line)
    
    match_nun_tsere_dagesh = re.compile('\u05e0' + '\u05b5' + '\u05bc')
    if re.search(match_nun_tsere_dagesh, line):
        line = re.sub(match_nun_tsere_dagesh, '\ufb40' + '\u05b5', line)
    
    match_nun_holam_dagesh  = re.compile('\u05e0' + '\u05b9' + '\u05bc')
    if re.search(match_nun_holam_dagesh, line):
        line = re.sub(match_nun_holam_dagesh, '\ufb40' + '\u05b9', line)
                                         
    ### Letter ס
    match_samech_dagesh = re.compile('\u05e1' + '\u05bc')
    if re.search(match_samech_dagesh, line):
        line = re.sub(match_samech_dagesh, '\ufb41', line)
    
    match_samech_sheva_dagesh = re.compile('\u05E1' + '\u05B0' + '\u05BC')
    if re.search(match_samech_sheva_dagesh, line):
        line = re.sub(match_samech_sheva_dagesh, '\uFB41' + '\u05B0', line)
    
    match_samech_hiriq_dagesh = re.compile('\u05E1' + '\u05B4' + '\u05BC')
    if re.search(match_samech_hiriq_dagesh, line):
        line = re.sub(match_samech_hiriq_dagesh, '\uFB41' + '\u05B4', line)
    
    match_samech_patach_dagesh = re.compile('\u05E1' + '\u05B7' + '\u05BC')
    if re.search(match_samech_patach_dagesh, line):
        line = re.sub(match_samech_patach_dagesh, '\uFB41' + '\u05B7' , line)     
    
    match_samech_qamats_dagesh = re.compile('\u05E1' + '\u05B8' + '\u05BC')
    if re.search(match_samech_qamats_dagesh, line):
        line = re.sub(match_samech_qamats_dagesh, '\uFB41' + '\u05B8', line)
    
    match_samech_segol_dagesh  = re.compile('\u05E1' + '\u05B6' + '\u05BC')
    if re.search(match_samech_segol_dagesh, line):
        line = re.sub(match_samech_segol_dagesh, '\uFB41' + '\u05B6', line)
    
    match_samech_holam_dagesh  = re.compile('\u05E1' + '\u05B9' + '\u05BC')
    if re.search(match_samech_holam_dagesh, line):
        line = re.sub(match_samech_holam_dagesh, '\uFB41' + '\u05B9', line)
    
    match_samekh_tsere_dagesh = re.compile('\u05e1' + '\u05b5' + '\u05bc')
    if re.search(match_samekh_tsere_dagesh, line):
        line = re.sub(match_samekh_tsere_dagesh, '\ufb41' + '\u05b5', line)
    
    match_samekh_qubuts_dagesh = re.compile('\u05e1' + '\u05bb' + '\u05bc')
    samekh_qubuts_dagesh = '\ufb41' + '\u05bb'
    if re.search(match_samekh_qubuts_dagesh, line):
        line = re.sub(match_samekh_qubuts_dagesh, samekh_qubuts_dagesh, line)
        
    ##### Letter ע
    
    match_ain_qamats_telisha = re.compile('\u05e2' + '\u05b8' + '\u05a0')
    ain_telisah_qamats = '\u05e2' + '\u05a0' + '\u05b8'
    if re.search(match_ain_qamats_telisha, line):
        line = re.sub(match_ain_qamats_telisha,  ain_telisah_qamats, line)
        
    #### Letter פ
    match_peh_sheva_dagesh = re.compile('\u05E4' + '\u05B0' + '\u05BC')
    if re.search(match_peh_sheva_dagesh, line):
        line = re.sub(match_peh_sheva_dagesh, '\uFB44' + '\u05B0', line)
    
    match_peh_dagesh = re.compile('\u05e4' + '\u05bc' )
    if re.search(match_peh_dagesh, line):
        line = re.sub(match_peh_dagesh, '\uFB44', line)
    
    match_peh_patach_dagesh = re.compile('\u05e4' + '\u05b7' + '\u05bc')
    if re.search(match_peh_patach_dagesh, line):
        line = re.sub(match_peh_patach_dagesh, '\ufb44' + '\u05b7', line)
    
    match_peh_qamats_dagesh = re.compile('\u05e4' + '\u05b8' + '\u05bc')
    if re.search(match_peh_qamats_dagesh, line):
        line = re.sub(match_peh_qamats_dagesh, '\uFB44' + '\u05B8', line)
    
    match_peh_segol_dagesh  = re.compile('\u05e4' + '\u05b6' + '\u05bc')
    if re.search(match_peh_segol_dagesh, line):
        line = re.sub(match_peh_segol_dagesh, '\uFB44' + '\u05B6', line)
    
    match_peh_tsere_dagesh = re.compile('\u05e4' + '\u05b5' + '\u05bc')
    if re.search(match_peh_tsere_dagesh, line):
        line = re.sub(match_peh_tsere_dagesh, '\uFB44' + '\u05b5', line)
    
    match_peh_holam_dagesh  = re.compile('\u05e4' + '\u05B9' + '\u05BC')
    if re.search(match_peh_holam_dagesh, line):
        line = re.sub(match_peh_holam_dagesh, '\uFB44' + '\u05B9', line)                                   
    
    match_peh_sheva_dagesh = re.compile('\u05e4' + '\u05B0' + '\u05BC')
    if re.search(match_peh_sheva_dagesh, line):
        line = re.sub(match_peh_sheva_dagesh, '\uFB44' + '\u05B0', line)
    
    match_peh_hiriq_dagesh = re.compile('\u05e4' + '\u05B4' + '\u05BC' )
    if re.search(match_peh_hiriq_dagesh, line):
        line = re.sub(match_peh_hiriq_dagesh, '\uFB44' + '\u05B4', line)
    
    match_peh_patach_dagesh = re.compile('\u05e4' + '\u05b7' + '\u05BC')
    if re.search(match_peh_patach_dagesh, line):
        line = re.sub(match_peh_patach_dagesh, '\uFB44' + '\u05b7', line)
    
    match_peh_qamats_dagesh = re.compile('\u05e4' + '\u05B8' + '\u05BC')
    if re.search(match_peh_qamats_dagesh, line):
        line = re.sub(match_peh_qamats_dagesh, '\uFB44' + '\u05B8', line)
    
    match_peh_hataf_qamats_dagesh = re.compile('\u05e4' + '\u05b3' + '\u05bc')
    pehdagesh_hataf_qamats = '\ufb44' + '\u05b3'
    if re.search(match_peh_hataf_qamats_dagesh, line):
        line = re.sub(match_peh_hataf_qamats_dagesh, pehdagesh_hataf_qamats, line)
    
    match_peh_segol_dagesh  = re.compile('\u05e4' + '\u05B6' + '\u05BC')
    if re.search(match_peh_segol_dagesh, line):
        line = re.sub(match_peh_segol_dagesh, '\uFB44' + '\u05B6' , line)
    
    match_peh_holam_dagesh  = re.compile('\u05e4' + '\u05B9' + '\u05BC')
    if re.search(match_peh_holam_dagesh, line):
        line = re.sub(match_peh_holam_dagesh, '\uFB44' + '\u05B9' , line)
    
    match_peh_qubuts_dagesh = re.compile('\u05e4' + '\u05bb' + '\u05bc')
    if re.search(match_peh_qubuts_dagesh, line):
        line = re.sub(match_peh_qubuts_dagesh, '\ufb44' + '\u05bb', line)
        
    ## Letter צ
    match_tsadi_patach_vav_segol_dagesh = '\u05e6' + '\u05b7' + '\u05d5' + '\u05b6'
    if re.search(match_tsadi_patach_vav_segol_dagesh, line):
        line = re.sub(match_tsadi_patach_vav_segol_dagesh, '\u05e6' + '\u05b7' + '\ufb35' + '\u05b6', line)
    
    match_tsadi_dagesh = re.compile('\u05e6' + '\u05bc')
    if re.search(match_tsadi_dagesh, line):
        line = re.sub(match_tsadi_dagesh, '\ufb46', line)
    
    match_tsadi_sheva_dagesh = re.compile('\u05e6' + '\u05B0' + '\u05bc')
    if re.search(match_tsadi_sheva_dagesh, line):
        line = re.sub(match_tsadi_sheva_dagesh, '\ufb46' + '\u05B0', line)
    
    match_tsadi_hiriq_dagesh = re.compile('\u05e6' + '\u05b4' + '\u05bc')
    if re.search(match_tsadi_hiriq_dagesh, line):
        line = re.sub(match_tsadi_hiriq_dagesh, '\uFB46' + '\u05b4', line)
    
    match_tsadi_patach_dagesh = re.compile('\u05e6' + '\u05B7' + '\u05bc')
    if re.search(match_tsadi_patach_dagesh, line):
        line = re.sub(match_tsadi_patach_dagesh, '\uFB46' + '\u05B7', line)
    
    match_tsadi_qamats_dagesh = re.compile('\u05e6' + '\u05B8' + '\u05bc')
    if re.search(match_tsadi_qamats_dagesh, line):
        line = re.sub(match_tsadi_qamats_dagesh, '\uFB46' + '\u05B8', line)
    
    match_tsadi_segol_dagesh  = re.compile('\u05e6' + '\u05B6' + '\u05bc')
    if re.search(match_tsadi_segol_dagesh, line):
        line = re.sub(match_tsadi_segol_dagesh, '\uFB46' + '\u05B6', line)
    
    match_tsadi_holam_dagesh  = re.compile('\u05e6' + '\u05B9' + '\u05bc')
    if re.search(match_tsadi_holam_dagesh, line):
        line = re.sub(match_tsadi_holam_dagesh, '\uFB46' + '\u05B9', line)
    
    match_tsadi_tsere_dagesh = re.compile('\u05e6' + '\u05b5' + '\u05bc')
    if re.search(match_tsadi_tsere_dagesh, line):
        line = re.sub(match_tsadi_tsere_dagesh, '\ufb46' + '\u05b5', line)
        
    match_tsadi_qubuts_dagesh = re.compile('\u05e6' + '\u05bb' + '\u05bc')
    if re.search(match_tsadi_tsere_dagesh, line):
        line = re.sub(match_tsadi_tsere_dagesh, '\ufb46' + '\u05bb', line)
        
    ## The letter ק
    match_quf_sheva_dagesh = re.compile('\u05E7' + '\u05B0' + '\u05BC')
    if re.search(match_quf_sheva_dagesh, line):
        line = re.sub(match_quf_sheva_dagesh, '\uFB47' + '\u05B0', line)
    
    match_quf_hiriq_dagesh = re.compile('\u05E7' + '\u05B4' + '\u05BC')
    if re.search(match_quf_hiriq_dagesh, line):
        line = re.sub(match_quf_hiriq_dagesh, '\uFB47' + '\u05B4', line)
    
    match_quf_patach_dagesh = re.compile('\u05E7' + '\u05B7' + '\u05BC')
    if re.search(match_quf_patach_dagesh, line):
        line = re.sub(match_quf_patach_dagesh, '\uFB47' + '\u05B7', line)
    
    match_quf_dagesh = re.compile('\u05E7' + '\u05bc')
    if re.search(match_quf_dagesh, line):
        line = re.sub(match_quf_dagesh, '\uFB47', line)
    
    match_quf_qamats_dagesh = re.compile('\u05E7' + '\u05B8' + '\u05BC')
    if re.search(match_quf_qamats_dagesh, line):
        line = re.sub(match_quf_qamats_dagesh, '\uFB47' + '\u05B8', line)
    
    match_quf_tsere_dagesh = re.compile('\u05e7' + '\u05b5' + '\u05bc')
    if re.search(match_quf_tsere_dagesh, line):
        line = re.sub(match_quf_tsere_dagesh, '\ufb47' + '\u05b5', line)
    
    match_quf_segol_dagesh  = re.compile('\u05E7' + '\u05B6' + '\u05BC')
    if re.search(match_quf_segol_dagesh, line):
        line = re.sub(match_quf_segol_dagesh, '\uFB47' + '\u05B6', line)
    
    match_quf_holam_dagesh  = re.compile('\u05E7' + '\u05B9' + '\u05BC')
    if re.search(match_quf_holam_dagesh, line):
        line = re.sub(match_quf_holam_dagesh, '\uFB47' + '\u05B9', line)
    
    match_qof_hataf_qamats_dagesh = re.compile('\u05e7' + '\u05b3' + '\u05bc')
    if re.search(match_qof_hataf_qamats_dagesh, line):
        line = re.sub(match_qof_hataf_qamats_dagesh, '\ufb47' + '\u05b3', line)
    
    match_qof_qubuts_dagesh = re.compile('\u05e7' + '\u05bb' + '\u05bc')
    if re.search(match_qof_qubuts_dagesh, line):
        line = re.sub(match_qof_qubuts_dagesh, '\ufb47' + '\u05bb', line )
    
    ################################################
    # What to do with dageshes in sins and shins??
    ################################################
    
    ## Letter שׂ

    match_shin_shin_dot_dagesh = re.compile('\u05e9' + '\u05c2' + '\u05bc')
    if re.search(match_shin_shin_dot_dagesh, line):
        line = re.sub(match_shin_shin_dot_dagesh, '\uFB2D', line)
    
    match_shin_sheva_dagesh_sin_dot = re.compile('\u05e9' + '\u05b0' + '\u05bc' + '\u05c2')
    if re.search(match_shin_sheva_dagesh_sin_dot, line):
        line = re.sub(match_shin_sheva_dagesh_sin_dot,'\uFB2D' + '\u05b0', line)
    
    match_shin_segol_dagesh_sin_dot = re.compile('\u05e9' + '\u05b6' + '\u05bc' + '\u05c2')
    if re.search( match_shin_segol_dagesh_sin_dot, line):
        line = re.sub( match_shin_segol_dagesh_sin_dot, '\ufb2d' + '\u05b6', line)
    
    match_shinsin_dot_dagesh = re.compile('\ufb2b' + '\u05bc')
    if re.search(match_shinsin_dot_dagesh, line):
        line = re.sub(match_shinsin_dot_dagesh, '\ufb2d', line)
    
    match_shin_sheva_sin_dot = re.compile('\u05e9' + '\u05B0' + '\u05C2')
    if re.search(match_shin_sheva_sin_dot, line):
        line = re.sub(match_shin_sheva_sin_dot, '\uFB2B' + '\u05B0', line)
    
    match_sin_hiriq_sin_dot = re.compile('\u05E9' + '\u05B4' + '\u05C2')
    if re.search(match_sin_hiriq_sin_dot, line):
        line = re.sub(match_sin_hiriq_sin_dot, '\uFB2B' + '\u05B4', line)
    
    match_shin_hiriq_dagesh_shin_dot = re.compile('\u05e9' + '\u05b4' + '\u05bc' + '\u05c1')
    if re.search(match_shin_hiriq_dagesh_shin_dot, line):
        line = re.sub(match_shin_hiriq_dagesh_shin_dot, '\ufb2c' + '\u05b4', line)
    
    match_shin_tsere_dagesh_sin_dot = re.compile('\u05e9' + '\u05b5' + '\u05bc' + '\u05c2')
    shin_dagesh_sin_dot_tsere = '\ufb2d' + '\u05b5'
    if re.search(match_shin_tsere_dagesh_sin_dot, line):
        line = re.sub(match_shin_tsere_dagesh_sin_dot, shin_dagesh_sin_dot_tsere, line)
    
    match_sin_tsere_sin_dot = re.compile('\u05e9'+ '\u05b5' + '\u05c2')
    if re.search(match_sin_tsere_sin_dot, line):
        line = re.sub(match_sin_tsere_sin_dot, '\ufb2b' + '\u05b5', line)
    
    match_sin_patach_sin_dot = re.compile('\u05E9' + '\u05B7' + '\u05C2')
    if re.search(match_sin_patach_sin_dot, line):
        line = re.sub(match_sin_patach_sin_dot, '\uFB2B' + '\u05B7', line )
    
    match_shin_qamats_sin_dot = re.compile('\u05E9' + '\u05B8' + '\u05C2')
    if re.search(match_shin_qamats_sin_dot, line):
        line = re.sub(match_shin_qamats_sin_dot, '\uFB2B' + '\u05B8', line)
    shin_qamats_dagesh_shin_dot = '\u05e9'+ '\u05b8' + '\u05bc' + '\u05c1'
    
    match_qamats_dagesh_shin_dot = re.compile(shin_qamats_dagesh_shin_dot)
    if re.search(match_qamats_dagesh_shin_dot, line):
        line = re.sub(match_qamats_dagesh_shin_dot, '\uFB2C' + '\u05B8', line)
    
    match_sin_segol_sin_dot = re.compile('\u05e9' + '\u05b6' + '\u05c2')
    if re.search(match_sin_segol_sin_dot, line):
        line = re.sub(match_sin_segol_sin_dot, '\ufb2b' + '\u05b6', line)
    
    match_shin_qubuts_dagesh_shin_dot = '\u05e9' + '\u05bb' + '\u05bc' + '\u05c1'
    if re.search(match_shin_qubuts_dagesh_shin_dot, line):
        line = re.sub(match_shin_qubuts_dagesh_shin_dot, '\ufb2c' + '\u05bb', line)
    #match_sin_segol_dagesh = '\u05E9' + '\u05B6' + '\u05BC' + '\u05C2'
    #if re.search(match_sin_segol_dagesh, line):
    #    line = re.sub(match_sin_segol_dagesh, '\uFB2B' + '\u05B6', line)
    
    match_shin_holam_dagesh_sin_dot = re.compile('\u05e9' + '\u05b9' + '\u05bc' + '\u05c2')
    if re.search(match_shin_holam_dagesh_sin_dot, line):
        line = re.sub(match_shin_holam_dagesh_sin_dot, '\uFB2D' + '\u05b9', line)
    
    match_shin_holam_meteg_sin_dot = re.compile('\u05e9' + '\u05b9' + '\u05bd' + '\u05c2')
    shinshindot_meteg_holam = '\ufb2b' + '\u05b9' + '\u05bd'
    if re.search( match_shin_holam_meteg_sin_dot, line):
        line = re.sub( match_shin_holam_meteg_sin_dot, '\ufb2b' + '\u05b9', line)
    #match_shin_holam_sin_dot = re.compile('\u05e9' + '\u05b9' + '\u05c2')
    
    match_shin_holam_shin_dot = re.compile('\u05e9' + '\u05b9' + '\u05c2')
    shinshindot_holam = '\ufb2b' + '\u05b9'
    if re.search(match_shin_holam_shin_dot, line):
        line = re.sub(match_shin_holam_shin_dot,shinshindot_holam, line)
    
    match_sin_holam_dagesh  = re.compile('\u05E9' + '\u05B9' + '\u05bc' + '\u05C2')
    if re.search(match_sin_holam_dagesh, line):
        line = re.sub(match_sin_holam_dagesh, '\uFB2C' + '\u05B9', line)
    
    match_sin_hiriq_meteg_sin_dot = re.compile('\u05e9' + '\u05b4' + '\u05bd' + '\u05c2')
    if re.search(match_sin_hiriq_meteg_sin_dot, line):
        line = re.sub(match_sin_hiriq_meteg_sin_dot, '\ufb2b' + '\u05bd', line)
    
    match_shin_hiriq_dagesh_sin_dot  = re.compile('\u05e9' + '\u05b4' + '\u05bc' + '\u05c2')
    if re.search(match_shin_hiriq_dagesh_sin_dot, line):
        line = re.sub(match_shin_hiriq_dagesh_sin_dot, '\ufb2d' + '\u05b4', line)
    
    match_shin_qubuts_sindot = re.compile('\u05e9' + '\u05bb' + '\u05c2')
    sinsindot_qubuts = '\ufb2b' + '\u05bb'
    if re.search(match_shin_qubuts_sindot, line):
        line = re.sub(match_shin_qubuts_sindot, sinsindot_qubuts, line)
     
    ## Letter שׁ    shin qamats dagesh shin dot
    match_shin_hiriq_dagesh_meteg_sin_dot = re.compile('\u05e9' + '\u05b4' + '\u05bc' + '\u05bd' + '\u05c2')
    shinsindotdagesh_hiriq_meteg = '\ufb2d' + '\u05b4' + '\u05bd' 
    if re.search(match_shin_hiriq_dagesh_meteg_sin_dot, line):
        line = re.sub(match_shin_hiriq_dagesh_meteg_sin_dot, shinsindotdagesh_hiriq_meteg, line)
    
    match_shin_sin_dot = re.compile('\u05e9' + '\u05c2')
    if re.search(match_shin_sin_dot, line):
        line = re.sub(match_shin_sin_dot, '\ufb2b', line)
    
    match_shin_segol_meteg_sin_dot =  re.compile('\u05e9' + '\u05b6' + '\u05bd' + '\u05c2')
    if re.search(match_shin_segol_meteg_sin_dot, line):
        line = re.sub(match_shin_segol_meteg_sin_dot, '\ufb2b' + '\u05b6' + '\u05bd', line)
    
    match_shin_qamats_dagesh_meteg_sin_dot =  re.compile('\u05e9' +'\u05b8' + '\u05bc' + '\u05bd' + '\u05c2')
    if re.search(match_shin_qamats_dagesh_meteg_sin_dot, line):
        line = re.sub(match_shin_qamats_dagesh_meteg_sin_dot, '\ufb2d' + '\u05b8' + '\u05bd', line)
    
    match_shin_qubuts_sin_dot = re.compile('\u05e9' + '\u05bb' + '\u05bc')
    sinsindot_qubuts = '\ufb2d' + '\u05bb'
    if re.search(match_shin_qubuts_sin_dot, line):
        line = re.sub(match_shin_qubuts_sin_dot, sinsindot_qubuts, line)
        
    ### Letter ש
    match_shin_dagesh_shin_dot = '\u05e9' + '\u05bc' + '\u05c1'
    if re.search(match_shin_dagesh_shin_dot, line):
        line = re.sub(match_shin_dagesh_shin_dot, '\ufb2c', line )
    
    match_shin_shin_dot = re.compile('\u05e9' + '\u05c1')
    if re.search(match_shin_shin_dot, line):
        line = re.sub(match_shin_shin_dot,'\uFB2A', line )
    
    match_shin_patach_dagesh_shin_dot  = re.compile('\u05e9' + '\u05b7' + '\u05bc' + '\u05c1')
    if re.search(match_shin_patach_dagesh_shin_dot, line):
        line = re.sub(match_shin_patach_dagesh_shin_dot, '\ufb2c' + '\u05b7', line)
    
    match_shin_shin_dot_dagesh = re.compile('\ufb2a' + '\u05bc')
    if re.search(match_shin_shin_dot_dagesh, line):
        line = re.sub(match_shin_shin_dot_dagesh, '\uFB2C', line)
    
    match_shin_meteg_shin_dot = re.compile('\u05e9' + '\u05bd' + '\u05c1')
    if re.search(match_shin_meteg_shin_dot, line):
        line = re.sub(match_shin_meteg_shin_dot, '\ufb2a' + '\u05bd', line)
    
    match_shin_dagesh_shindot_atnachta = re.compile('\u05e9' + '\u05bc' + '\u05c1' + '\u0591')
    if re.search(match_shin_dagesh_shindot_atnachta, line):
        line = re.sub(match_shin_dagesh_shindot_atnachta, '\uFB2C' + '\u0591', line)
    
    match_shin_sheva_shin_dot = re.compile('\u05E9' + '\u05B0' + '\u05C1')
    if re.search(match_shin_sheva_shin_dot, line):
        line = re.sub(match_shin_sheva_shin_dot, '\uFB2A' + '\u05B0', line)
    
    match_shin_sheva_dagesh_shin_dot = re.compile('\u05e9' + '\u05b0' + '\u05bc' + '\u05c1')
    if re.search(match_shin_sheva_dagesh_shin_dot, line):
        line = re.sub(match_shin_sheva_dagesh_shin_dot, '\ufb2c' + '\u05b0', line)
    
    match_shin_hiriq_shin_dot = re.compile('\u05E9' + '\u05B4' + '\u05C1')
    if re.search(match_shin_hiriq_shin_dot, line):
        line = re.sub(match_shin_hiriq_shin_dot,'\uFB2A' + '\u05B4', line)
    
    match_shin_hiriq_dagesh_shin_dot = re.compile('\u05e9' + '\u05b4' + '\u05bc' + '\u05c1')
    if re.search(match_shin_hiriq_dagesh_shin_dot, line):
        line = re.sub(match_shin_hiriq_dagesh_shin_dot, '\ufb2c' + '\u05b4', line)
    
    match_shin_hiriq_dagesh_meteg_shin_dot = '\u05e9' + '\u05b4' + '\u05bc' + '\u05bd' + '\u05c1'
    if re.search(match_shin_hiriq_dagesh_meteg_shin_dot, line):
        line = re.sub(match_shin_hiriq_dagesh_meteg_shin_dot, '\ufb2c' + '\u05b4' + '\u05bd', line)
    
    match_shin_patach_shin_dot = re.compile('\u05E9' + '\u05B7' + '\u05C1')
    if re.search(match_shin_patach_shin_dot, line):
        line = re.sub(match_shin_patach_shin_dot, '\uFB2A' + '\u05B7', line)
    
    match_shin_qamats_shin_dot = re.compile('\u05e9' + '\u05b8' + '\u05c1')
    if re.search(match_shin_qamats_shin_dot, line):
        line = re.sub(match_shin_qamats_shin_dot, '\ufb2a' + '\u05b8', line)
    
    match_shin_qamats_dagesh_shin_dot = re.compile('\u05e9' + '\u05b8' + '\u05bc' + '\u05c2')
    if re.search(match_shin_qamats_dagesh_shin_dot, line):
        line = re.sub(match_shin_qamats_dagesh_shin_dot, '\uFB2D' + '\u05b8', line )
    
    match_shin_shin_dot_dagesh = re.compile('\u05e9' + '\u05c1' + '\u05bc')
    if re.search(match_shin_shin_dot_dagesh, line):
        line = re.sub(match_shin_shin_dot_dagesh, '\ufb2c', line)
    
    match_shin_qamats_dagesh_shin_dot = re.compile('\u05E9' + '\u05B8' + '\u05bc' + '\u05c1')
    if re.search(match_shin_qamats_dagesh_shin_dot, line):
        line = re.sub(match_shin_qamats_dagesh_shin_dot, '\uFB2D' + '\u05B8', line)
    
    match_shin_segol_shin_dot  = re.compile('\u05e9' +  '\u05B6' + '\u05c1')
    if re.search(match_shin_segol_shin_dot, line):
        line = re.sub(match_shin_segol_shin_dot,'\uFB2A' + '\u05B6', line)
    
    match_shin_segol_dagesh_shin_dot = re.compile('\u05e9' + '\u05b6' + '\u05bc' + '\u05c1')
    if re.search(match_shin_segol_dagesh_shin_dot, line):
        line = re.sub(match_shin_segol_dagesh_shin_dot, '\ufb2c' + '\u05b6', line )
    
    match_shin_segol_meteg_shin_dot = re.compile('\u05e9' + '\u05b6' + '\u05bd' + '\u05c1')
    if re.search(match_shin_segol_meteg_shin_dot, line):
        line = re.sub(match_shin_segol_meteg_shin_dot, '\ufb2a' + '\u05b6' + '\u05bd', line)                                          
    
    match_shin_holam_shin_dot  = re.compile('\u05E9' + '\u05B9' + '\u05C1')
    if re.search(match_shin_holam_shin_dot, line):
        line = re.sub(match_shin_holam_shin_dot, '\uFB2A' + '\u05B9', line)
    
    match_shin_holam_meteg_shin_dot = re.compile('\u05e9' + '\u05b9' + '\u05bd' + '\u05c1')
    shinwshindot_holam_meteg = '\ufb2a' + '\u05b9' + '\u05bd'
    if re.search(match_shin_holam_meteg_shin_dot, line):
        line = re.sub(match_shin_holam_meteg_shin_dot, shinwshindot_holam_meteg, line)
    
    match_shin_qubuts_shin_dot = re.compile('\u05E9' + '\u05BB' + '\u05C1')
    if re.search(match_shin_qubuts_shin_dot, line):
        line = re.sub(match_shin_qubuts_shin_dot, '\uFB2A' + '\u05BB', line)
    
    match_shin_qubuts_meteg_shin_dot = re.compile('\u05e9' + '\u05bb' + '\u05bd' + '\u05c1')
    shinshindot_qubuts_meteg = '\ufb2a' + '\u05bb' + '\u05bd'
    if re.search(match_shin_qubuts_meteg_shin_dot, line):
        line = re.sub(match_shin_qubuts_meteg_shin_dot,shinshindot_qubuts_meteg, line)
    #match_shin_shin_dot_separate = re.compile('\u05E9' + '\u05C1')
    #if re.search(match_shin_shin_dot_separate, line):
        #line = re.sub(match_shin_shin_dot_separate,'\uFB2A', line)
    
    match_shin_tsere_dagesh_meteg_shin_dot = re.compile('\u05e9' + '\u05b5' + '\u05bc' + '\u05bd' + '\u05c1')
    if re.search(match_shin_tsere_dagesh_meteg_shin_dot, line):
        line = re.sub(match_shin_tsere_dagesh_meteg_shin_dot, '\ufb2c' + '\u05b5' + '\u05bd', line)
    
    
    match_shin_tsere_shindot = re.compile('\u05e9' + '\u05b5' + '\u05c1')
    if re.search(match_shin_tsere_shindot, line):
        line = re.sub(match_shin_tsere_shindot, '\uFB2A' + '\u05b5', line)
    
    match_shin_tsere_dagesh_shindot_keter = re.compile('\u05e9' + '\u05b5' + '\u05bc' + '\u05c1')
    if re.search(match_shin_tsere_dagesh_shindot_keter, line):
        line = re.sub(match_shin_tsere_dagesh_shindot_keter, '\ufb2c' + '\u05b5', line)
    
    match_shin_shindot_dagesh_tsere_ginsburg = re.compile('\u05e9' + '\u05c1' + '\u05bc' + '\u05b5')
    if re.search(match_shin_shindot_dagesh_tsere_ginsburg, line):
        line = re.sub(match_shin_shindot_dagesh_tsere_ginsburg, '\ufb2c' + '\u05b5', line)
    
    match_shin_tsere_dagesh_shindot_keter = re.compile('\u05e9' + '\u05b5' + '\u05bc' + '\u05c1')
    if re.search(match_shin_tsere_dagesh_shindot_keter, line):
        line = re.sub(match_shin_tsere_dagesh_shindot_keter, '\ufb2c' + '\u05b5', line)
    
    match_shin_hiriq_meteg_shin_dot = re.compile('\u05e9' + '\u05b4' + '\u05bd' + '\u05c1')
    if re.search(match_shin_hiriq_meteg_shin_dot, line):
        line = re.sub(match_shin_hiriq_meteg_shin_dot, '\ufb2a' + '\u05b4' + '\u05bd', line)
    ### Here
    
    match_shin_qubuts_shindot = re.compile('\u05e9' + '\u05bb' + '\u05c1')
    
    match_shin_meteg_shin_dot = '\u05e9' + '\u05bd' + '\u05c2'
    if re.search(match_shin_meteg_shin_dot, line):
        line = re.sub(match_shin_meteg_shin_dot, '\ufb2b', line)
    
    match_shin_tsere_meteg_shin_dot = re.compile('\u05e9' + '\u05b5' + '\u05bd' + '\u05c1')
    if re.search(match_shin_tsere_meteg_shin_dot, line):
        line = re.sub(match_shin_tsere_meteg_shin_dot, '\ufb2a' + '\u05b5' + '\u05bd', line)
    
    match_shin_holam_dagesh_shin_dot = re.compile('\u05e9' + '\u05b9' + '\u05bc' + '\u05c1')
    if re.search(match_shin_holam_dagesh_shin_dot, line):
        line = re.sub(match_shin_holam_dagesh_shin_dot, '\ufb2c' + '\u05b9', line)
    
    match_shin_qamats_meteg_sin_dot = re.compile('\u05e9' + '\u05b8' + '\u05bd' + '\u05c2')
    if re.search(match_shin_qamats_meteg_sin_dot, line):
        line = re.sub(match_shin_qamats_meteg_sin_dot, '\ufb2b' + '\u05b8' + '\u05bd', line)
    
    match_shin_qamats_dagesh_meteg_shin_dot  = re.compile('\u05e9' + '\u05b8' + '\u05bc' + '\u05bd' + '\u05c1')
    if re.search(match_shin_qamats_dagesh_meteg_shin_dot, line):
        line = re.sub(match_shin_qamats_dagesh_meteg_shin_dot, '\ufb2c' + '\u05b8' + '\u05bd', line)
    
    match_shin_dagesh_shin_dot_tipeha = re.compile('\u05e9' + '\u05bc' + '\u05c1' + '\u0596')
    if re.search(match_shin_dagesh_shin_dot_tipeha, line):
        line = re.sub(match_shin_dagesh_shin_dot_tipeha, '\ufb2c' + '\u0596', line)
    
    match_shin_hatafpatach_shindot = re.compile('\u05e9' + '\u05b2' + '\u05c1')
    shinshindot_hataf_patach = '\ufb2a' + '\u05b2'
    if re.search(match_shin_hatafpatach_shindot, line):
        line = re.sub(match_shin_hatafpatach_shindot, shinshindot_hataf_patach, line)
    
    ## Letter ת
    match_tav_dagesh = re.compile('\u05EA' + '\u05bc')
    if re.search(match_tav_dagesh, line):
        line = re.sub(match_tav_dagesh, '\uFB4A', line)
    
    match_tav_sheva_dagesh = re.compile('\u05EA' + '\u05B0' + '\u05BC')
    if re.search(match_tav_sheva_dagesh, line):
        line = re.sub(match_tav_sheva_dagesh, '\uFB4A' + '\u05B0', line)
    
    match_tav_hiriq_dagesh = re.compile('\u05EA' + '\u05B4' + '\u05BC')
    if re.search(match_tav_hiriq_dagesh, line):
        line = re.sub(match_tav_hiriq_dagesh, '\uFB4A' + '\u05B4', line)
    
    match_tav_patach_dagesh = re.compile('\u05ea' + '\u05b7' + '\u05bc')
    if re.search(match_tav_patach_dagesh, line):
        line = re.sub(match_tav_patach_dagesh, '\uFB4A' + '\u05B7', line)
    
    match_tav_qamats_dagesh = re.compile(('\u05ea' + '\u05b8' + '\u05bc'))
    if re.search(match_tav_qamats_dagesh, line):
        line = re.sub(match_tav_qamats_dagesh,'\uFB4A' + '\u05B8', line )
    
    match_tav_segol_dagesh  = re.compile('\u05EA' + '\u05B6' + '\u05BC')
    if re.search(match_tav_segol_dagesh, line):
        line = re.sub(match_tav_segol_dagesh, '\uFB4A' + '\u05B6', line)
        
    match_yod_segol_dagesh = re.compile('\u05d9' + '\u05bc' + '\u05b6')
    if re.search(match_yod_segol_dagesh, line):
        line = re.sub(match_yod_segol_dagesh, '\uFB39' + '\u05B6', line)
    
    match_tav_tsere_dagesh = re.compile('\u05ea' + '\u05b5' + '\u05bc')
    if re.search(match_tav_tsere_dagesh, line):
        line = re.sub(match_tav_tsere_dagesh, '\ufb4a' + '\u05b5', line )
    
    match_tav_holam_dagesh  = re.compile('\u05EA' + '\u05B9' + '\u05BC')
    if re.search(match_tav_holam_dagesh, line):
        line = re.sub(match_tav_holam_dagesh, '\uFB4A' + '\u05B9', line)
    
    match_tav_qubuts_dagesh = re.compile('\u05ea' + '\u05bb' + '\u05bc')
    if re.search(match_tav_qubuts_dagesh, line):
        #print('match for match_tav_qubuts_dagesh, line == ' + line)
        line = re.sub(match_tav_qubuts_dagesh, '\uFB4A' + '\u05BB', line )
    
    match_tav_hataf_qamats_dagesh = '\u05ea' + '\u05b3' + '\u05bc'
    if re.search(match_tav_hataf_qamats_dagesh, line):
        line = re.sub(match_tav_hataf_qamats_dagesh, '\ufb4a' + '\u05b3', line)
    
   ## stumah and petuchah markers

    match_stumah_marker = re.compile('\u05C3' + ' ' + '\u05E1')
    if re.search(match_stumah_marker, line):
        line = re.sub(match_stumah_marker, '\u05C3' + '\u05E1', line)
    
    match_petuchah_marker = re.compile('\u05C3' + ' ' + '\u05E4')
    if re.search(match_petuchah_marker, line):
        line = re.sub(match_petuchah_marker, '\u05C3' + '\u05E4', line)
        
    # replace colon with sof pasuq
    match_colon = re.compile(':')
    if re.search(match_colon, line):
        line = re.sub(match_colon, sof_pasuq, line)
    
    ## Corrections in the Divine Name
    
    adonai_without_holam = re.compile('\u05d0' + '\u05b2' + '\u05d3' + '\u05e0' + '\u05b8')
    adonai_w_holam = '\u05d0' + '\u05b2' + '\u05d3' + '\u05B9' + '\u05e0' + '\u05b8'
    if re.search(adonai_without_holam, line):
        line = re.sub(adonai_without_holam, adonai_w_holam, line)
    
    ginsburg_yeho = '\u05d9' + '\u05b0' + '\u05d4' + '\ufb4b' + '\u05b8'
    match_ginsburg_yeho = re.compile(ginsburg_yeho)
    yeho_replacement =  '\u05d9' + '\u05b0' + '\u05d4' + '\u05b9' + '\u05d5' + '\u05b8'
    if re.search(match_ginsburg_yeho, line):
        line = re.sub(match_ginsburg_yeho, yeho_replacement, line)
    ## Here
    
    match_yeho = re.compile('\u05d9' + '\u05b0' + '\u05d4' + '\u05d5' + '\u05ba' + '\u05b8')
    yeho_replacement =  '\u05d9' + '\u05b0' + '\u05d4' + '\u05b9' + '\u05d5' + '\u05b8'
    if re.search(match_yeho, line):
        #print('Found match for match_yeho, line == ' + line)
        line = re.sub(match_yeho, yeho_replacement, line)
        #print('line after match yeho ' + line)
    
    YEHO_W_QAMATS = '\u05d9' + '\u05b0' + '\u05d4' + '\u05d5' + '\u05B8'
    match_yeho_w_qamats = re.compile(YEHO_W_QAMATS)
    if re.search(match_yeho_w_qamats, line):
        #print('Found match for yeho_w_qamats')
        line = re.sub(match_yeho_w_qamats, yeho_replacement, line)
        #print('Line after yeho_w_qamats:  ' + line)
    
    ### This the real match for ginsburg
    match_ginsburg_yeho = re.compile('\u05d9' + '\u05d4' + '\ufb4b' + '\u05b8')
    ginsburg_replacement_yeho = '\u05d9' + '\u05d4' + '\u05B9' + '\u05D5' + '\u05B8'
    if re.search(match_ginsburg_yeho, line):
        #print('Found match ginsburg yeho')
        line = re.sub(match_ginsburg_yeho, ginsburg_replacement_yeho, line)                                         
    
    match_yehovi = re.compile('\u05d9' + '\u05b1' + '\u05d4' + '\u05d5' + '\u05ba' + '\u05b4')
    yehovi_replacement = '\u05d9' + '\u05B1' + '\u05d4' + '\u05b9'  + '\u05d5' + '\u05b4'
    if re.search(match_yehovi, line):
        line = re.sub(match_yehovi, yehovi_replacement, line)
    
    match_ginsburg_yehovi = re.compile('\u05d9' + '\u05b1' + '\u05d4' + '\ufb4b' + '\u05b4')
    ginsburg_yehovi_replacement = '\u05d9' + '\u05b1' + '\u05d4' + '\u05b9' + '\u05d5' + '\u05b4'
    if re.search(match_ginsburg_yehovi, line):
        line = re.sub(match_ginsburg_yehovi, ginsburg_yehovi_replacement, line)
    
    match_laadonai_defective_ginsburg = re.compile('\u05dc' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4' + '\u05d5' + '\u05ba' + '\u05b8')
    laadonai_corrected = '\u05dc' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4' + '\u05B9' + '\u05d5' + '\u05b8'
    if re.search(match_laadonai_defective_ginsburg, line):
        line = re.sub(match_laadonai_defective_ginsburg, laadonai_corrected, line)
    
    match_ginsburg_laadonai = re.compile('\u05dc' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4' + '\ufb4b' + '\u05b8')
    if re.search(match_ginsburg_laadonai, line):
        line = re.sub(match_ginsburg_laadonai, laadonai_corrected, line)
    
    ginsburg_vaadonai_w_meteg = re.compile('\u05d5' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4' + '\ufb4b' + '\u05b8')
    
    ginsburg_vaadonai_w_meteg_fixed = '\u05d5' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4' + '\u05B9' + '\u05D5' + '\u05B8'
    if re.search(ginsburg_vaadonai_w_meteg, line):
        line = re.sub(ginsburg_vaadonai_w_meteg, ginsburg_vaadonai_w_meteg_fixed, line)
    
    match_keter_layho_w_o_meteg = re.compile('\u05dc' + '\u05b7' + '\u05d9' + '\u05d4' + '\u05d5' + '\u05b8')
    keter_layho_w_holam = '\u05dc' + '\u05b7' + '\u05d9' + '\u05d4' + '\u05B9'  + '\u05d5' + '\u05b8'
    if re.search(match_keter_layho_w_o_meteg, line):
        line = re.sub(match_keter_layho_w_o_meteg, keter_layho_w_holam, line)
    
    laadonai_w_meteg_replacement =   re.compile('\u05dc' + '\u05b7' + '\u05bd' + '\u05d9'+ '\u05d4'+ '\u05B9' + '\u05d5' + '\u05b8')
    baadonai_w_meteg = re.compile('\u05d1' + '\u05bc' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4'+ '\u05d5' + '\u05ba' + '\u05b8')
    baadonai_w_meteg_replacement = '\u05d1' + '\u05bc' + '\u05b7' + '\u05bd'+ '\u05d9'+ '\u05d4'+ '\u05B9' + '\u05d5' + '\u05b8'
    if re.search(baadonai_w_meteg, line):
        line = re.sub(baadonai_w_meteg, baadonai_w_meteg_replacement, line)
    
    baadonai_w_meteg_and_rafe = re.compile('\u05d1' + '\u05bf' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4'+ '\u05d5' + '\u05ba' + '\u05b8')
    
    baadonai_w_meteg_and_rafe_replacement = '\u05d1' + '\u05bf' + '\u05b7' + '\u05bd' + '\u05d9'+ '\u05d4'+ '\u05B9' + '\u05d5' + '\u05b8'
    if re.search(baadonai_w_meteg_and_rafe, line):
        line = re.sub(baadonai_w_meteg_and_rafe, baadonai_w_meteg_and_rafe_replacement, line)
    lamed_meteg_alef_and_holam_haser = re.compile('\u05dc' + '\u05bd' + '\u05d0' + '\u05ba')
    lamed_w_meteg_alef_and_holam = '\u05dc' + '\u05bd' + '\u05B9' + '\u05d0'
    if re.search(lamed_meteg_alef_and_holam_haser, line):
        line =  re.sub(lamed_meteg_alef_and_holam_haser, lamed_w_meteg_alef_and_holam, line)
    lo_with_holam_haser = re.compile('\u05dc' + '\u05a5' + '\u05d0' + '\u05ba')
    lo_w_holam_fixed = '\u05dc' + '\u05b9' + '\u05a5' + '\u05d0'
    if re.search(lo_with_holam_haser, line):
        line = re.sub(lo_with_holam_haser, lo_w_holam_fixed, line)
    keter_laadonai = re.compile('\u05dc' + '\u05b7' + '\u05bd' + '\u05d9' + '\u05d4' + '\u05d5' + '\u05b8')
    keter_laadonai_replacement = '\u05dc' + '\u05b7' + '\u05bd' + '\u05d9\u05d4' + '\u05B9' +  '\u05d5' + '\u05b8'
    if re.search(keter_laadonai, line):
        line = re.sub(keter_laadonai, keter_laadonai_replacement, line)
        
    ##### This is the real match for keter
    keter_yeho = '\u05d9' + '\u05b0' + '\u05d4'  + '\u05d5' + '\u05b8'
    keter_yeho_replacement = '\u05d9' + '\u05b0' + '\u05d4' + '\u05b9' + '\u05d5' + '\u05b8'
    if re.search(keter_yeho, line):
        ### This call is correct.
        line = re.sub(keter_yeho, keter_yeho_replacement, line)
    match_yod_sheva_telisha_he_vavholam = re.compile('\u05d9' + '\u05b0' + '\u05a0' + '\u05d4' + '\ufb4b' + '\u05b8')
    
    yod_sheva_telisha_he_holam_vav_qamats = '\u05d9' + '\u05b0' + '\u05a0' + '\u05d4'  + '\u05B9' + '\u05D5' + '\u05b8'
    if re.search(match_yod_sheva_telisha_he_vavholam, line):
        line = re.sub(match_yod_sheva_telisha_he_vavholam, yod_sheva_telisha_he_holam_vav_qamats, line)
    
    match_yod_sheva_telisha_he_vavholam = re.compile('\u05d9' + '\u05b0' + '\u05a0' + '\u05d4' + '\ufb4b' + '\u05b8')
    if re.search(match_yod_sheva_telisha_he_vavholam, line):
        line = re.sub(match_yod_sheva_telisha_he_vavholam, yod_sheva_telisha_he_holam_vav_qamats, line)


    return line

# %%
## Ginsburg files

in_keter_directory_str = '/Users/alberthembd/Documents/Documents/Ginsburg/Real_edition_of_Ginsburg_Bible/2)Keter/Keter_Source/'
out_keter_directory_str = '/Users/alberthembd/Documents/Documents/Ginsburg/Real_edition_of_Ginsburg_Bible/2)Keter/Keter_revised/'
in_Ginsburg_directory_str = '/Users/alberthembd/Documents/Documents/Ginsburg/Real_edition_of_Ginsburg_Bible/1)Actual_Ginsburg_Text'
out_Ginsburg_directory_str = '/Users/alberthembd/Desktop/Ginsburg_Source/revised/restore_rafes'
loopCounter = 0

try:
    ## First, convert the Keter files.
    in_tanakh_directory_str = os.fsencode (in_keter_directory_str)
    out_tanakh_directory_str  = os.fsencode(out_keter_directory_str)
    file_list = []
    #print('In tanakh directory == ' + in_keter_directory_str)
    for file in os.listdir(in_tanakh_directory_str):
        filename = os.fsdecode(file)
        #print('Up here, file name == '  +  filename)
        if filename.endswith('.txt'):
            file_list.append(filename)
        else:
            continue
        
        file_list.sort()
    for i in file_list:
        tanakh_file = open(in_keter_directory_str + '/' + str(i), 'r', encoding = 'utf-8')
        #print('Tanakh file == ' + str(tanakh_file))
        revised_tanakh_file = open(out_keter_directory_str + '/' + str(i), 'w', encoding = 'utf-8')
        with tanakh_file, revised_tanakh_file:
            for line in tanakh_file:
                print('Calling replace_strings from keter processing')
                line = replace_strings(line)
                line = line.strip() + '\n'
                print('Keter: ' + line)
                revised_tanakh_file.write(line)
            
    ###Process Ginsburg files
    
    ## Now, convert the Ginsburg files.
    in_tanakh_directory_str = os.fsencode (in_Ginsburg_directory_str)
    out_tanakh_directory_str  = os.fsencode(out_Ginsburg_directory_str)
    ginsburg_file_list = []
    #print('In tanakh directory == ' + in_Ginsburg_directory_str)
    for file in os.listdir(in_tanakh_directory_str):
        filename = os.fsdecode(file)
        #print('Up here, file name == '  +  filename)
        if filename.endswith('.txt'):
            ginsburg_file_list.append(filename)
        else:
            continue
        
        ginsburg_file_list.sort()
    for i in ginsburg_file_list:
        tanakh_file = open(in_Ginsburg_directory_str + '/' + str(i), 'r', encoding = 'utf-8')
        print('Tanakh file == ' + str(tanakh_file))
        revised_tanakh_file = open(out_Ginsburg_directory_str + '/' + str(i), 'w', encoding = 'utf-8')
        with tanakh_file, revised_tanakh_file:
            for line in tanakh_file:
                print('Loop counter == ' + str(loopCounter))
                print('Loop counter is ' + str(type(loopCounter)))
                if loopCounter == 0:
                    print('Line == ' + line)
                    line = convert_book_title(line)
                elif 'Chapter' in line:
                    line = chapterTitle(line)
                elif line[0].isdigit():
                    line = convert_verse_number(line)
                    line = line + chr(10)
                    print('Line is:')
                    print(line)
                if line == 'None':
                    line = chr(13)
                print('calling replace strings from Ginsburg')
                line = replace_strings(line)
                line = line.strip() + '\n'
                print('Ginsburg after: ' + line)
                revised_tanakh_file.write(line)
                loopCounter = loopCounter + 1
            loopCounter = 0
            
                

            
            
    
    
except:
    raise
